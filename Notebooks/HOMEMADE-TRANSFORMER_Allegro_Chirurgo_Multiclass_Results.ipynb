# %%
# !pip install transformers accelerate rouge_score sacremoses torchvision

import os
import re
import random
import logging 
import warnings
from pathlib import Path
import concurrent.futures
from functools import partial
import shutil
from tqdm import tqdm
import multiprocessing
import sys

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from PIL import Image

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from rouge_score import rouge_scorer
import torchvision.models as tv_models
from sklearn.model_selection import train_test_split
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

import random
from sklearn.utils.class_weight import compute_class_weight

from transformers import (
    GPT2Tokenizer, GPT2Config, GPT2Model, GPT2LMHeadModel
)

warnings.filterwarnings('ignore')
logging.getLogger("transformers").setLevel(logging.ERROR)

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    stream=sys.stdout
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device in uso: {device}")

# ----------------------------------------------------------
# ------------------ VARIABILI IMPORTANTI ------------------
# ----------------------------------------------------------

Kaggle = True
typeOfClassification = "multiclass"  # "binary" o "ternary" o "multiclass"

TRAIN_MAIN_MODEL = True   # funziona un po' a cazzo  -  Se True, allena il modello principale; se False, carica il modello già salvato 
TRAIN_VAE = True          # funziona un po' a cazzo  -  Se True, allena il VAE; se False, carica il VAE già salvato
MODEL_SAVE_DIR = "./saved_model"
MAIN_MODEL_PATH = os.path.join(MODEL_SAVE_DIR, "model.pth")
VAE_MODEL_PATH = os.path.join(MODEL_SAVE_DIR, "vae.pth")

IMAGE_RESIZE= 384

TRAINING_SET_SIZE = 0.6
VALIDATION_SET_SIZE = 0.2
TEST_SET_SIZE = 0.2

BATCH_SIZE_DATALOADERS = 8

FOCAL_LOSS = False if typeOfClassification.lower() == "binary" else True

# ----------------- AZIONI DA FARE -----------------
# IMPOSTA TUTTO A TRUE PER ESEGUIRE TUTTO
CLEAN_DATASET = True
RECONSTRUCT_IMAGES = True
# -----------------------------------------

# ----------------- MAIN -----------------
NUM_EPOCHS_MAIN_MODEL = 10
LEARNING_RATE = 1e-4
EARLY_STOPPING_PATIENCE = 3

WEIGHT_DECAY = 1e-4
TEACHER_FORCING_RATE = 0.6
ALPHA_MAIN_MODEL = 0.4

# -----------------------------------------
# ------------------ VAE ------------------
NUM_EPOCHS_VAE = 10
LEARNING_RATE_VAE = 5e-5
EARLY_STOPPING_PATIENCE_VAE = 3

ENCODER_VAE_TRAINABLE_LAYERS = 6
LATENT_DIM_VAE = 512
# -----------------------------------------

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token

tokenizer.add_special_tokens({'bos_token': '<bos>'})

transform = transforms.Compose([
    transforms.Resize((IMAGE_RESIZE, IMAGE_RESIZE)),
    transforms.ToTensor(),
])

if(Kaggle):
    PROJECTIONS_PATH = '/kaggle/input/chest-xrays-indiana-university/indiana_projections.csv'
    REPORTS_PATH = '/kaggle/input/chest-xrays-indiana-university/indiana_reports.csv'
    IMG_DIR = '/kaggle/input/chest-xrays-indiana-university/images/images_normalized'
    
    # Kaggle funziona a cazzo, se questi path non vi funzionano commentateli e decommentate questi sotto

    # PROJECTIONS_PATH = '/kaggle/input/indiana_projections.csv'
    # REPORTS_PATH = '/kaggle/input/indiana_reports.csv'
    # IMG_DIR = '/kaggle/input/images/images_normalized'
    
    REPORTS_OUTPUT_PATH = '/kaggle/working/indiana_reports_cleaned.csv'
    PROJECTIONS_OUTPUT_PATH = '/kaggle/working/indiana_projections_cleaned.csv'
    DISCARDED_DIR = '/kaggle/working/dataset/discarded'

print(f"Directory dei report: {REPORTS_PATH}")
print(f"Directory delle proiezioni: {PROJECTIONS_PATH}")
print(f"Directory delle immagini: {IMG_DIR}")
print(f"Directory delle immagini scartate: {DISCARDED_DIR}")

cpu_count = multiprocessing.cpu_count()
cpus_to_use = cpu_count - 1 if cpu_count > 1 else 1
print(f"Num workers: {cpus_to_use}")
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.1+cu121)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.2.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17->transformers) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.17->transformers) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.17->transformers) (2024.2.0)
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 27.7 MB/s eta 0:00:00
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=d330a70eddd5f5804cd2dd4afb7214914eb0e93667d4da67149a9efea0c0a4cb
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: sacremoses, rouge_score
# Successfully installed rouge_score-0.1.2 sacremoses-0.1.1
# Device in uso: cuda
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Directory dei report: /kaggle/input/chest-xrays-indiana-university/indiana_reports.csv
# Directory delle proiezioni: /kaggle/input/chest-xrays-indiana-university/indiana_projections.csv
# Directory delle immagini: /kaggle/input/chest-xrays-indiana-university/images/images_normalized
# Directory delle immagini scartate: /kaggle/working/dataset/discarded
# Num workers: 3

# %% [markdown]
# # 1

# %%
if CLEAN_DATASET:

    def identifica_uid_sbagliati(initial_uids, valid_uids):
        return initial_uids - valid_uids

    def leggi_csv(path):
        try:
            return pd.read_csv(path)
        except Exception as e:
            logging.error(f"Errore nel caricamento del CSV {path}: {e}")
            return None

    def valida_projections(row, valid_projections):
        return (
            pd.notna(row['filename']) and 
            pd.notna(row['projection']) and 
            row['projection'] in valid_projections
        )

    def filtra_uid_con_2_foto(projections_df, images_dir):
        if not isinstance(images_dir, Path):
            images_dir = Path(images_dir)
        
        projection_counts = projections_df.groupby(['uid', 'projection']).size().unstack(fill_value=0)
        
        candidate_uids = projection_counts[
            (projection_counts.get('Frontal', 0) == 1) & 
            (projection_counts.get('Lateral', 0) == 1)
            ].index
        
        all_image_files = set(f.name for f in images_dir.glob("*.dcm.png"))
        valid_uids = set()
        
        for uid in candidate_uids:
            uid_rows = projections_df[projections_df['uid'] == uid]
            projection_files = uid_rows['filename'].tolist()
            
            if all(filename in all_image_files for filename in projection_files):
                uid_image_files = set(f.name for f in images_dir.glob(f"{uid}_*.dcm.png"))
                if uid_image_files == set(projection_files):
                    valid_uids.add(uid)
        
        return valid_uids

    def rimuovi_immagini(image_path_str):
        image_path = Path(image_path_str)
        try:
            if image_path.exists():
                image_path.unlink()
                logging.info(f"Rimosso immagine: {image_path.name}")
        except Exception as e:
            logging.error(f"Errore nella rimozione dell'immagine {image_path.name}: {e}")

    def muovi_immagini(image_path_str, dest_dir_str):
        src_path = Path(image_path_str)
        dest_dir = Path(dest_dir_str)
        try:
            if src_path.exists():
                dest_path = dest_dir / src_path.name
                shutil.move(str(src_path), str(dest_path))
                logging.info(f"Spostata immagine: {src_path.name} -> {dest_path}")
        except Exception as e:
            logging.error(f"Errore nello spostamento dell'immagine {src_path.name}: {e}")

    def conta_immagini_rimanenti(images_dir):
        if not isinstance(images_dir, Path):
            images_dir = Path(images_dir)
        if images_dir.exists():
            return len(list(images_dir.glob("*.dcm.png")))
        else:
            logging.warning(f"Directory delle immagini {images_dir} non esiste.")
            return 0

    def raccogli_immagini_da_processare(images_dir, invalid_uids, final_projections_df):
        if not isinstance(images_dir, Path):
            images_dir = Path(images_dir)
        images_to_process = []
        if images_dir.exists():
            for uid in invalid_uids:
                images = images_dir.glob(f"{uid}_*.dcm.png")
                images_to_process.extend(str(img) for img in images)
            expected_images = set(final_projections_df['filename'])
            all_image_files = set(f.name for f in images_dir.glob("*.dcm.png"))
            extra_images = all_image_files - expected_images
            images_to_process.extend(str(images_dir / img) for img in extra_images)
            images_to_process = list(set(images_to_process))
        else:
            logging.warning(f"La directory {images_dir} non esiste.")
        logging.info(f"Totale immagini da scartare/spostare: {len(images_to_process)}")
        return images_to_process

    def prepara_directory_discard(action, discarded_dir, images_dir):
        if not isinstance(images_dir, Path):
            images_dir = Path(images_dir)
        if action == "DISCARD":
            if not discarded_dir:
                discarded_dir = images_dir.parent / "discarded"
            else:
                discarded_dir = Path(discarded_dir)
            discarded_dir.mkdir(parents=True, exist_ok=True)
        return discarded_dir

    def remove_image(image_path_str):
        rimuovi_immagini(image_path_str)

    def move_image(image_path_str, dest_dir_str):
        muovi_immagini(image_path_str, dest_dir_str)

    def esegui_operazioni_sulle_immagini(images_to_process, action, discarded_dir, num_workers=None):
        if images_to_process:
            if action == "CLEAN":
                operation_func = remove_image
                logging.info("Rimozione fisica delle immagini scartate...")
            else:  # DISCARD
                operation_func = partial(move_image, dest_dir_str=str(discarded_dir))
                logging.info("Spostamento immagini scartate nella cartella 'discarded'...")
            with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
                list(tqdm(executor.map(operation_func, images_to_process), total=len(images_to_process)))

    def save_final_csvs(final_reports_df, final_projections_df, reports_output_path, projections_output_path):
        try:
            final_reports_df.to_csv(reports_output_path, index=False)
            final_projections_df.to_csv(projections_output_path, index=False)
            logging.info("Salvati CSV con i record validi.")
        except Exception as e:
            logging.error(f"Errore nel salvataggio dei CSV finali: {e}")

    def create_discard_csvs(reports_df, projections_df, valid_uids, discard_output_dir, reports_path, projections_path):
        discard_output_dir = Path(discard_output_dir)
        discard_output_dir.mkdir(parents=True, exist_ok=True)
        discard_reports_path = discard_output_dir / f"Discard_{Path(reports_path).name}"
        discard_projections_path = discard_output_dir / f"Discard_{Path(projections_path).name}"
        invalid_reports_df = reports_df[~reports_df['uid'].isin(valid_uids)]
        invalid_projections_df = projections_df[~projections_df['uid'].isin(valid_uids)]
        invalid_reports_df.to_csv(discard_reports_path, index=False)
        invalid_projections_df.to_csv(discard_projections_path, index=False)
        logging.info("Generati i file CSV Discard_* con i record scartati.")

    def log_cleanup_summary(initial_reports, initial_projections, final_reports_df, final_projections_df, images_to_process, action):
        removed_reports = initial_reports - len(final_reports_df)
        removed_projections = initial_projections - len(final_projections_df)
        removed_images = len(images_to_process)
        logging.info("\n=== Riepilogo Pulizia ===")
        logging.info(f"Reports scartati (o spostati): {removed_reports}")
        logging.info(f"Projections scartati (o spostati): {removed_projections}")
        logging.info(f"Immagini scartate (o spostate): {removed_images}")

    def print_analyze_summary(removed_reports, removed_projections, removed_images):
        print(
            f"\nAnalisi completata.\n"
            f"Reports scartati: {removed_reports}\n"
            f"Projections scartati: {removed_projections}\n"
            f"Immagini scartate: {removed_images}"
        )

    def parse_and_filter_problems(row, problem_counts, threshold):
        problems_str = row["Problems"]
        mesh_str = row["MeSH"] if "MeSH" in row else ""
        if isinstance(problems_str, str) and problems_str.strip().lower() == "normal":
            return ["normal"]
        if isinstance(mesh_str, str) and mesh_str.strip().lower() == "normal":
            return ["normal"]
        if pd.isna(problems_str) or not problems_str.strip():
            return []
        splitted = [p.strip() for p in problems_str.split(';') if p.strip()]
        filtered = [p for p in splitted if problem_counts.get(p, 0) >= threshold]
        if len(filtered) > 1:
            filtered = [filtered[0]]
        return filtered

    def calcola_frequenze_problemi(valid_reports_df):
        problem_counts = {}
        for probs in valid_reports_df['Problems'].dropna():
            if probs.strip().lower() == "normal":
                continue
            for prob in probs.split(';'):
                prob = prob.strip()
                if prob:
                    problem_counts[prob] = problem_counts.get(prob, 0) + 1
        return problem_counts

    def cleanup_datasets(
        reports_path,
        projections_path,
        images_dir,
        discarded_dir,           
        reports_output_path,     
        projections_output_path, 
        action="ANALYZE",
        num_workers=None,
        random_seed=42,
        threshold=50
    ):
        logging.info("Inizio elaborazione del dataset...")
        logging.info(f"Modalità: {action}")
        if action not in ["ANALYZE", "CLEAN", "DISCARD"]:
            raise ValueError("action deve essere 'ANALYZE', 'CLEAN' o 'DISCARD'")
        random.seed(random_seed)
        if not isinstance(images_dir, Path):
            images_dir = Path(images_dir)
        essential_report_fields = ['MeSH', 'Problems', 'image', 'findings', 'impression']
        valid_projections_set = {'Frontal', 'Lateral'}
        
        logging.info("Caricamento dei CSV...")
        reports_df = leggi_csv(reports_path)
        projections_df = leggi_csv(projections_path)
        if reports_df is None or projections_df is None:
            logging.error("Errore nel caricamento dei CSV. Terminazione del processo.")
            return

        # Filtro per eliminare i record con "Technical Quality of Image Unsatisfactory"
        reports_df = reports_df[~reports_df['Problems'].str.contains("Technical Quality of Image Unsatisfactory", na=False)]
        
        initial_reports = len(reports_df)
        initial_projections = len(projections_df)
        all_uids_before = set(reports_df['uid'])
        logging.info(f"Record iniziali - Reports: {initial_reports}, Projections: {initial_projections}")

        # 1) Rimozione record reports con campi essenziali vuoti
        logging.info("Fase 1: Rimozione record reports con campi essenziali vuoti...")
        mask_notna = reports_df[essential_report_fields].notna().all(axis=1)
        mask_non_empty = (reports_df[essential_report_fields]
                        .apply(lambda x: x.astype(str).str.strip())
                        .ne('')).all(axis=1)
        valid_fields_mask = mask_notna & mask_non_empty
        valid_reports_df = reports_df[valid_fields_mask].copy()

        invalid_uids_due_to_essential_fields = set(reports_df.loc[~valid_fields_mask, 'uid'])
        projections_df = projections_df[~projections_df['uid'].isin(invalid_uids_due_to_essential_fields)].copy()
        logging.info(f"Reports validi (dopo campi essenziali): {len(valid_reports_df)}")
        logging.info(f"Projections rimanenti dopo rimozione UID invalidi: {len(projections_df)}")

        # 2) Rimozione record projections non validi
        logging.info("Fase 2: Rimozione record projections con campi vuoti/invalidi...")
        proj_mask = projections_df.apply(valida_projections, axis=1, args=(valid_projections_set,))
        valid_projections_df = projections_df[proj_mask].copy()
        invalid_uids_due_to_projections = set(projections_df.loc[~proj_mask, 'uid'])
        valid_reports_df = valid_reports_df[~valid_reports_df['uid'].isin(invalid_uids_due_to_projections)].copy()
        logging.info(f"Projections validi: {len(valid_projections_df)}")
        logging.info(f"Reports rimanenti dopo rimozione UID con proiezioni non valide: {len(valid_reports_df)}")

        # 3) Verifica 1 Frontal + 1 Laterale (prima passata) + presenza file immagine
        logging.info("Fase 3: Verifica 1 Frontal + 1 Laterale (prima passata)...")
        uids_with_2_proj = filtra_uid_con_2_foto(valid_projections_df, images_dir)
        valid_reports_df = valid_reports_df[valid_reports_df['uid'].isin(uids_with_2_proj)].copy()
        valid_projections_df = valid_projections_df[valid_projections_df['uid'].isin(uids_with_2_proj)].copy()
        logging.info(f"Reports dopo filtraggio 1 Frontal + 1 Laterale: {len(valid_reports_df)}")
        logging.info(f"Projections dopo filtraggio 1 Frontal + 1 Laterale: {len(valid_projections_df)}")

        # Raccolta degli UID validi finali
        final_uids = set(valid_reports_df['uid'])
        # Raccolta degli UID invalidi
        invalid_uids = identifica_uid_sbagliati(all_uids_before, final_uids)
        images_to_process = raccogli_immagini_da_processare(images_dir, invalid_uids, valid_projections_df)


        if action in ["CLEAN", "DISCARD"]:
            discarded_dir = prepara_directory_discard(action, discarded_dir, images_dir)
            esegui_operazioni_sulle_immagini(images_to_process, action, discarded_dir, num_workers)
            save_final_csvs(valid_reports_df, valid_projections_df, reports_output_path, projections_output_path)
            if action == "DISCARD":
                create_discard_csvs(reports_df, projections_df, final_uids, discarded_dir, reports_path, projections_path)
            remaining_images = conta_immagini_rimanenti(images_dir)
            logging.info(f"Immagini rimanenti in {images_dir}: {remaining_images}")
        else:
            logging.info("Modalità ANALYZE: nessuna modifica sul filesystem.")
            remaining_images = conta_immagini_rimanenti(images_dir)

        removed_reports = initial_reports - len(valid_reports_df)
        removed_projections = initial_projections - len(valid_projections_df)
        removed_images = len(images_to_process)
        
        log_cleanup_summary(initial_reports, initial_projections, valid_reports_df, valid_projections_df, images_to_process, action)
        
        print(f"\nnumero_di_projections: {len(valid_projections_df)}")
        print(f"numero_di_reports: {len(valid_reports_df)}")
        print(f"numero_di_immagini: {remaining_images}")

        if action == "ANALYZE":
            print_analyze_summary(removed_reports, removed_projections, removed_images)

    cleanup_datasets(
        reports_path=REPORTS_PATH,
        projections_path=PROJECTIONS_PATH,
        images_dir=IMG_DIR,
        discarded_dir=DISCARDED_DIR,
        reports_output_path=REPORTS_OUTPUT_PATH,
        projections_output_path=PROJECTIONS_OUTPUT_PATH,
        action="DISCARD",  # "ANALYZE" o "CLEAN" o "DISCARD"
        num_workers=cpus_to_use,
        random_seed=42,
        threshold=20
    )
    print("fine clean")
# Out:
# 100%|██████████| 1896/1896 [00:18<00:00, 103.95it/s]
# numero_di_projections: 5574
# numero_di_reports: 2728
# numero_di_immagini: 7470
# fine clean

# %% [markdown]
# # 2

# %%
if not os.path.exists(PROJECTIONS_OUTPUT_PATH) or not os.path.exists(REPORTS_OUTPUT_PATH):
    raise FileNotFoundError("I file CSV cleaned non sono stati trovati. Assicurati di aver eseguito correttamente la cella di pulizia del dataset.")

logging.info("Fase 2: Creazione del DataFrame finale...")

df_image = pd.read_csv(PROJECTIONS_OUTPUT_PATH)
df_report = pd.read_csv(REPORTS_OUTPUT_PATH)

df_report = df_report[~df_report['Problems'].str.contains("Technical Quality of Image Unsatisfactory", na=False)]

unique_problems = set()
for problems in df_report['Problems'].dropna():
    for problem in problems.split(';'):
        unique_problems.add(problem.strip())
unique_problems = sorted(unique_problems)

print("\nElenco dei problemi unici nel dataset:")
for problem in unique_problems:
    print(f"- {problem}")

df = pd.DataFrame({'front_img': [], 'lateral_img': [], ' captions': [], 'problems': []})

common_uids = set(df_image['uid']).intersection(set(df_report['uid']))
for uid in common_uids:
    front_image = df_image.loc[(df_image['uid'] == uid) & (df_image['projection'] == 'Frontal')]
    lateral_img = df_image.loc[(df_image['uid'] == uid) & (df_image['projection'] == 'Lateral')]
    report_rows = df_report.loc[df_report['uid'] == uid]
    
    if not front_image.empty and not lateral_img.empty and not report_rows.empty:
        caption = report_rows['findings'].values[0]
        problems = report_rows['Problems'].values[0]
        
        df = pd.concat([df, pd.DataFrame([{
            'front_img': front_image.iloc[0]['filename'],
            'lateral_img': lateral_img.iloc[0]['filename'],
            'captions': caption,
            'problems': problems
        }])], axis=0)

df['front_img'] = IMG_DIR + '/' + df['front_img']
df['lateral_img'] = IMG_DIR + '/' + df['lateral_img']

df = df.reset_index(drop=True)
print("\nEcco una parte del DataFrame finale dopo la pulizia:")
print(df.head(10)) 
print(f"Dimensioni finali: {df.shape}")

categories = {
    "Sistema Polmonare": [
        "Airspace Disease",
        "Bronchiectasis",
        "Bronchiolitis",
        "Bullous Emphysema",
        "Calcified Granuloma",
        "Cystic Fibrosis",
        "Emphysema",
        "Infiltrate",
        "Lung",
        "Lung Diseases, Interstitial",
        "Lung, Hyperlucent",
        "Mass",
        "Nodule",
        "Opacity",
        "Pneumonia",
        "Pneumothorax",
        "Pulmonary Artery",
        "Pulmonary Atelectasis",
        "Pulmonary Congestion",
        "Pulmonary Disease, Chronic Obstructive",
        "Pulmonary Edema",
        "Pulmonary Emphysema",
        "Pulmonary Fibrosis",
        "Sclerosis",
        "Fibrosis",
        "Granuloma",
        "Granulomatous Disease",
        "Pericardial Effusion",
        "Pleural Effusion",
        "Consolidation",
        "Lucency",
        "Shift",
        "Volume Loss",
        "Adipose Tissue",
        "Density",
        "Epicardial Fat",
    ],
    "Sistema Cardiovascolare": [
        "Aorta",
        "Aorta, Thoracic",
        "Atherosclerosis",
        "Cardiac Shadow",
        "Cardiomegaly",
        "Heart",
        "Heart Atria",
        "Heart Failure",
        "Heart Ventricles",
        "Hypertension, Pulmonary",
    ],
    "Sistema Muscoloscheletrico": [
        "Arthritis",
        "Bone Diseases, Metabolic",
        "Deformity",
        "Fractures, Bone",
        "Kyphosis",
        "Lumbar Vertebrae",
        "Scoliosis",
        "Spine",
        "Spinal Fusion",
        "Spondylosis",
        "Thoracic Vertebrae",
        "Osteophyte",
        "Hyperostosis, Diffuse Idiopathic Skeletal",
    ],
    "Altri Problemi": [
        "Blister",
        "Calcinosis",
        "Cavitation",
        "Cicatrix",
        "Cysts",
        "Diaphragm",
        "Diaphragmatic Eventration",
        "Foreign Bodies",
        "Markings",
        "Mastectomy",
        "Mediastinum",
        "Nipple Shadow",
        "Shoulder",
        "Colonic Interposition",
        "Hernia, Diaphragmatic",
        "Hernia, Hiatal",
        "Breast Implants",
        "Catheters, Indwelling",
        "Implanted Medical Device",
        "Medical Device",
        "Stents",
        "Surgical Instruments",
        "Sutures",
        "Tube, Inserted",
    ],
    "Nessun Problema": [
        "normal"
    ]
}

def assign_categories(problems, categories_dict):
    if not isinstance(problems, str) or problems.strip().lower() == "normal":
        return "Nessun Problema"

    if typeOfClassification == "binary":
        return "Malato"
    elif typeOfClassification == "ternary":
        problems_list = [p.strip() for p in problems.split(';') if p.strip()]
        for p in problems_list:
            if p in categories_dict.get("Sistema Polmonare", []):
                return "Problemi Polmonari"
        return "Altri Problemi" # Se nessuna corrispondenza, assegna "Altri Problemi"
    
    elif typeOfClassification == "multiclass":
        assigned_categories = set()
        problems_list = [p.strip() for p in problems.split(';') if p.strip()]
        for p in problems_list:
            for category, problem_list in categories_dict.items():
                if p in problem_list:
                    assigned_categories.add(category)
                    break  # Evita assegnazioni multiple alla stessa categoria
        if len(assigned_categories) == 0:
            return "Altri Problemi"
        else:
            return assigned_categories.pop()

df['categories'] = df['problems'].apply(lambda x: assign_categories(x, categories))
df = df.dropna(subset=['categories'])
df = df[df['categories'] != 'Multiple']
df = df.reset_index(drop=True)

print("\nDataFrame dopo assegnazione macro-categorie:")
print(df.head(10))
print(f"Dimensioni finali post-filtraggio categorie: {df.shape}")


if typeOfClassification == "binary":
    risk_mapping = {
        'Nessun Problema': 0,
        'Malato': 1
    }
elif typeOfClassification == "ternary":
    risk_mapping = {
        'Nessun Problema': 0,
        'Problemi Polmonari': 1,
        'Altri Problemi': 2
    }
elif typeOfClassification == "multiclass":
    risk_mapping = {
        'Nessun Problema': 0,
        'Sistema Polmonare': 1,
        'Sistema Cardiovascolare': 2,
        'Sistema Muscoloscheletrico': 3,
        'Altri Problemi': 4
    }
else:
    raise ValueError("Tipo di classificazione non supportato.")

if typeOfClassification == "binary":
    num_class_pred = 2
elif typeOfClassification == "ternary":
    num_class_pred = 3
elif typeOfClassification == "multiclass":
    num_class_pred = 5
else:
    raise ValueError("Tipo di classificazione non supportato.")



def assign_categories(problems, categories_dict):
    if not isinstance(problems, str) or problems.strip().lower() == "normal":
        return "Nessun Problema"

    if typeOfClassification == "binary":
        return "Malato"
    elif typeOfClassification == "ternary":
        problems_list = [p.strip() for p in problems.split(';') if p.strip()]
        for p in problems_list:
            if p in categories_dict.get("Sistema Polmonare", []):
                return "Problemi Polmonari"
        return "Altri Problemi"
    
    elif typeOfClassification == "multiclass":
        assigned_categories = set()
        problems_list = [p.strip() for p in problems.split(';') if p.strip()]
        for p in problems_list:
            for category, problem_list in categories_dict.items():
                if p in problem_list:
                    assigned_categories.add(category)
                    break
        if len(assigned_categories) == 0:
            return "Altri Problemi" 
        else:
            return assigned_categories.pop()

df['categories'] = df['problems'].apply(lambda x: assign_categories(x, categories))
df = df.dropna(subset=['categories'])
df = df[df['categories'] != 'Multiple']
df = df.reset_index(drop=True)

print("\nDataFrame dopo assegnazione macro-categorie:")
print(df.head(10))
print(f"Dimensioni finali post-filtraggio categorie: {df.shape}")
# Out:
# Elenco dei problemi unici nel dataset:
# - Adipose Tissue
# - Airspace Disease
# - Aorta
# - Aorta, Thoracic
# - Aortic Aneurysm
# - Arthritis
# - Atherosclerosis
# - Blister
# - Blood Vessels
# - Bone Diseases, Metabolic
# - Bone and Bones
# - Breast Implants
# - Bronchiectasis
# - Bronchiolitis
# - Bronchitis
# - Bullous Emphysema
# - Calcified Granuloma
# - Calcinosis
# - Cardiac Shadow
# - Cardiomegaly
# - Catheters, Indwelling
# - Cavitation
# - Cervical Vertebrae
# - Cholelithiasis
# - Cicatrix
# - Colonic Interposition
# - Consolidation
# - Contrast Media
# - Costophrenic Angle
# - Cystic Fibrosis
# - Cysts
# - Deformity
# - Density
# - Diaphragm
# - Diaphragmatic Eventration
# - Dislocations
# - Emphysema
# - Epicardial Fat
# - Fibrosis
# - Foreign Bodies
# - Fractures, Bone
# - Funnel Chest
# - Granuloma
# - Granulomatous Disease
# - Heart
# - Heart Atria
# - Heart Failure
# - Heart Ventricles
# - Hemopneumothorax
# - Hemothorax
# - Hernia, Diaphragmatic
# - Hernia, Hiatal
# - Humerus
# - Hyperostosis, Diffuse Idiopathic Skeletal
# - Hypertension, Pulmonary
# - Implanted Medical Device
# - Infiltrate
# - Kyphosis
# - Lucency
# - Lumbar Vertebrae
# - Lung
# - Lung Diseases, Interstitial
# - Lung, Hyperlucent
# - Lymph Nodes
# - Lymph nodes
# - Markings
# - Mass
# - Mastectomy
# - Mediastinum
# - Medical Device
# - Nipple Shadow
# - No Indexing
# - Nodule
# - Opacity
# - Osteophyte
# - Pectus Carinatum
# - Pericardial Effusion
# - Pleural Effusion
# - Pneumonectomy
# - Pneumonia
# - Pneumoperitoneum
# - Pneumothorax
# - Pulmonary Artery
# - Pulmonary Atelectasis
# - Pulmonary Congestion
# - Pulmonary Disease, Chronic Obstructive
# - Pulmonary Edema
# - Pulmonary Emphysema
# - Pulmonary Fibrosis
# - Ribs
# - Sarcoidosis
# - Sclerosis
# - Scoliosis
# - Shift
# - Shoulder
# - Spinal Fusion
# - Spine
# - Spondylosis
# - Stents
# - Subcutaneous  Emphysema
# - Subcutaneous Emphysema
# - Sulcus
# - Surgical Instruments
# - Sutures
# - Thickening
# - Thoracic Vertebrae
# - Thoracic vertebrae
# - Trachea, Carina
# - Tube, Inserted
# - Tuberculosis
# - Volume Loss
# - normal
#
# Ecco una parte del DataFrame finale dopo la pulizia:
#                                            front_img  \
# 0  /kaggle/input/chest-xrays-indiana-university/i...
# 1  /kaggle/input/chest-xrays-indiana-university/i...
# 2  /kaggle/input/chest-xrays-indiana-university/i...
# 3  /kaggle/input/chest-xrays-indiana-university/i...
# 4  /kaggle/input/chest-xrays-indiana-university/i...
# 5  /kaggle/input/chest-xrays-indiana-university/i...
# 6  /kaggle/input/chest-xrays-indiana-university/i...
# 7  /kaggle/input/chest-xrays-indiana-university/i...
# 8  /kaggle/input/chest-xrays-indiana-university/i...
# 9  /kaggle/input/chest-xrays-indiana-university/i...
#
#                                          lateral_img   captions  \
# 0  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 1  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 2  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 3  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 4  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 5  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 6  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 7  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 8  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 9  /kaggle/input/chest-xrays-indiana-university/i...        NaN
#
#                                             problems  \
# 0                                             normal
# 1                      Cardiomegaly;Pulmonary Artery
# 2  Pulmonary Disease, Chronic Obstructive;Bullous...
# 3                         Osteophyte;Thickening;Lung
# 4                                             normal
# 5        Pulmonary Atelectasis;Spondylosis;Arthritis
# 6                                             normal
# 7                        Calcified Granuloma;Density
# 8                                Calcified Granuloma
# 9                                             normal
#
#                                             captions
# 0  The cardiac silhouette and mediastinum size ar...
# 1  Borderline cardiomegaly. Midline sternotomy XX...
# 2  There are diffuse bilateral interstitial and a...
# 3  The cardiomediastinal silhouette and pulmonary...
# 4  Heart size and mediastinal contour are within ...
# 5  The cardiac contours are normal. XXXX basilar ...
# 6  The heart, pulmonary XXXX and mediastinum are ...
# 7  The XXXX examination consists of frontal and l...
# 8  The cardiomediastinal silhouette is within nor...
# 9  Cardiomediastinal silhouette and pulmonary vas...
# Dimensioni finali: (2728, 5)
#
# DataFrame dopo assegnazione macro-categorie:
#                                            front_img  \
# 0  /kaggle/input/chest-xrays-indiana-university/i...
# 1  /kaggle/input/chest-xrays-indiana-university/i...
# 2  /kaggle/input/chest-xrays-indiana-university/i...
# 3  /kaggle/input/chest-xrays-indiana-university/i...
# 4  /kaggle/input/chest-xrays-indiana-university/i...
# 5  /kaggle/input/chest-xrays-indiana-university/i...
# 6  /kaggle/input/chest-xrays-indiana-university/i...
# 7  /kaggle/input/chest-xrays-indiana-university/i...
# 8  /kaggle/input/chest-xrays-indiana-university/i...
# 9  /kaggle/input/chest-xrays-indiana-university/i...
#
#                                          lateral_img   captions  \
# 0  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 1  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 2  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 3  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 4  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 5  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 6  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 7  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 8  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 9  /kaggle/input/chest-xrays-indiana-university/i...        NaN
#
#                                             problems  \
# 0                                             normal
# 1                      Cardiomegaly;Pulmonary Artery
# 2  Pulmonary Disease, Chronic Obstructive;Bullous...
# 3                         Osteophyte;Thickening;Lung
# 4                                             normal
# 5        Pulmonary Atelectasis;Spondylosis;Arthritis
# 6                                             normal
# 7                        Calcified Granuloma;Density
# 8                                Calcified Granuloma
# 9                                             normal
#
#                                             captions         categories
# 0  The cardiac silhouette and mediastinum size ar...    Nessun Problema
# 1  Borderline cardiomegaly. Midline sternotomy XX...  Sistema Polmonare
# 2  There are diffuse bilateral interstitial and a...     Altri Problemi
# 3  The cardiomediastinal silhouette and pulmonary...  Sistema Polmonare
# 4  Heart size and mediastinal contour are within ...    Nessun Problema
# 5  The cardiac contours are normal. XXXX basilar ...  Sistema Polmonare
# 6  The heart, pulmonary XXXX and mediastinum are ...    Nessun Problema
# 7  The XXXX examination consists of frontal and l...  Sistema Polmonare
# 8  The cardiomediastinal silhouette is within nor...  Sistema Polmonare
# 9  Cardiomediastinal silhouette and pulmonary vas...    Nessun Problema
# Dimensioni finali post-filtraggio categorie: (2728, 6)
#
# DataFrame dopo assegnazione macro-categorie:
#                                            front_img  \
# 0  /kaggle/input/chest-xrays-indiana-university/i...
# 1  /kaggle/input/chest-xrays-indiana-university/i...
# 2  /kaggle/input/chest-xrays-indiana-university/i...
# 3  /kaggle/input/chest-xrays-indiana-university/i...
# 4  /kaggle/input/chest-xrays-indiana-university/i...
# 5  /kaggle/input/chest-xrays-indiana-university/i...
# 6  /kaggle/input/chest-xrays-indiana-university/i...
# 7  /kaggle/input/chest-xrays-indiana-university/i...
# 8  /kaggle/input/chest-xrays-indiana-university/i...
# 9  /kaggle/input/chest-xrays-indiana-university/i...
#
#                                          lateral_img   captions  \
# 0  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 1  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 2  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 3  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 4  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 5  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 6  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 7  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 8  /kaggle/input/chest-xrays-indiana-university/i...        NaN
# 9  /kaggle/input/chest-xrays-indiana-university/i...        NaN
#
#                                             problems  \
# 0                                             normal
# 1                      Cardiomegaly;Pulmonary Artery
# 2  Pulmonary Disease, Chronic Obstructive;Bullous...
# 3                         Osteophyte;Thickening;Lung
# 4                                             normal
# 5        Pulmonary Atelectasis;Spondylosis;Arthritis
# 6                                             normal
# 7                        Calcified Granuloma;Density
# 8                                Calcified Granuloma
# 9                                             normal
#
#                                             captions         categories
# 0  The cardiac silhouette and mediastinum size ar...    Nessun Problema
# 1  Borderline cardiomegaly. Midline sternotomy XX...  Sistema Polmonare
# 2  There are diffuse bilateral interstitial and a...     Altri Problemi
# 3  The cardiomediastinal silhouette and pulmonary...  Sistema Polmonare
# 4  Heart size and mediastinal contour are within ...    Nessun Problema
# 5  The cardiac contours are normal. XXXX basilar ...  Sistema Polmonare
# 6  The heart, pulmonary XXXX and mediastinum are ...    Nessun Problema
# 7  The XXXX examination consists of frontal and l...  Sistema Polmonare
# 8  The cardiomediastinal silhouette is within nor...  Sistema Polmonare
# 9  Cardiomediastinal silhouette and pulmonary vas...    Nessun Problema
# Dimensioni finali post-filtraggio categorie: (2728, 6)

# %% [markdown]
# # 3

# %%
class LoadDataset(Dataset):
    def __init__(self, df):
        self.front_images = df['front_img'].values
        self.lateral_imgs = df['lateral_img'].values
        self.captions = df['captions'].values
        self.problems = df['problems'].values
        self.zone_categories = df['categories'].values
        
    def __getitem__(self, uid):
        front_image_path = str(self.front_images[uid])
        lateral_img_path = str(self.lateral_imgs[uid])
        
        front_image = Image.open(front_image_path).convert("RGB")
        lateral_img = Image.open(lateral_img_path).convert("RGB")
        
        front_image = transform(front_image)
        lateral_img = transform(lateral_img)

        caption = str(self.captions[uid])
        problem = str(self.problems[uid])
        categories = self.zone_categories[uid]
        
        encoded_caption = tokenizer(
            caption,
            max_length=128,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )

        risk_label = risk_mapping.get(categories, 0) 
        risk_one_hot = F.one_hot(torch.tensor(risk_label), num_classes=num_class_pred).float()
        
        return {
            'front_pixel_values': front_image,
            'lateral_pixel_values': lateral_img,
            'input_ids_caption': encoded_caption['input_ids'].squeeze(0),
            'attention_mask_caption': encoded_caption['attention_mask'].squeeze(0),
            'categories': risk_one_hot
        }

    def __len__(self):
        return len(self.front_images)


print("fine load dataset")
# Out:
# fine load dataset

# %% [markdown]
# # 4

# %%
train_df, test_df = train_test_split(
    df,
    test_size=TEST_SET_SIZE,
    stratify=df['categories'],
    random_state=42
)

train_df, valid_df = train_test_split(
    train_df,
    test_size=VALIDATION_SET_SIZE,
    stratify=train_df['categories'],
    random_state=42
)

print("Distribuzione delle classi nel Train set:")
print(train_df['categories'].value_counts())
print("\nDistribuzione delle classi nel Validation set:")
print(valid_df['categories'].value_counts())
print("\nDistribuzione delle classi nel Test set:")
print(test_df['categories'].value_counts())

train_ds = LoadDataset(train_df)
valid_ds = LoadDataset(valid_df)
test_ds  = LoadDataset(test_df)

print("fine ghgh")
# Out:
# Distribuzione delle classi nel Train set:
# categories
# Nessun Problema               655
# Altri Problemi                503
# Sistema Polmonare             395
# Sistema Muscoloscheletrico    150
# Sistema Cardiovascolare        42
# Name: count, dtype: int64
#
# Distribuzione delle classi nel Validation set:
# categories
# Nessun Problema               164
# Altri Problemi                126
# Sistema Polmonare              99
# Sistema Muscoloscheletrico     37
# Sistema Cardiovascolare        11
# Name: count, dtype: int64
#
# Distribuzione delle classi nel Test set:
# categories
# Nessun Problema               205
# Altri Problemi                157
# Sistema Polmonare             124
# Sistema Muscoloscheletrico     47
# Sistema Cardiovascolare        13
# Name: count, dtype: int64
# fine ghgh

# %% [markdown]
# # 5

# %%
class ResNetEncoder(nn.Module):
    def __init__(self, trainable_layers=6):
        super(ResNetEncoder, self).__init__()
        self.model = models.resnet50(pretrained=True)
        self.model.fc = nn.Identity()
        
        for param in self.model.parameters():
            param.requires_grad = False
        
        self._unfreeze_last_layers(trainable_layers)

    def _unfreeze_last_layers(self, trainable_layers):
        children = list(self.model.children())
        for layer in children[-trainable_layers:]:
            for param in layer.parameters():
                param.requires_grad = True

    def forward(self, x):
        return self.model(x)

print("fine creazione resnet")
# Out:
# fine creazione resnet

# %% [markdown]
# # 6

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=512):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(1) 
        self.register_buffer('pe', pe)

    def forward(self, x):
        seq_len = x.size(0)
        x = x + self.pe[:seq_len]
        return x

class SimpleTransformerDecoder(nn.Module):
    def __init__(self, vocab_size, d_model=768, num_layers=2, nhead=8, dim_feedforward=2048, dropout=0.1, max_len=512):
        super(SimpleTransformerDecoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model, max_len)
        decoder_layer = nn.TransformerDecoderLayer(d_model, nhead, dim_feedforward, dropout)
        self.transformer_decoder = nn.TransformerDecoder(decoder_layer, num_layers)
        self.fc_out = nn.Linear(d_model, vocab_size)
    
    def generate_square_subsequent_mask(self, sz):
        mask = torch.triu(torch.ones(sz, sz) * float('-inf'), diagonal=1)
        return mask

class AllegroChirurgoModel(nn.Module):
    def __init__(self, num_classes=8, teacher_forcing_rate=0.5):
        super(AllegroChirurgoModel, self).__init__()
        self.teacher_forcing_rate = teacher_forcing_rate
        
        self.encoder_front = ResNetEncoder(trainable_layers=6)
        self.encoder_lateral = ResNetEncoder(trainable_layers=6)
        
        self.image_proj = nn.Linear(2048, 768)
        
        self.classifier = nn.Sequential(
            nn.Linear(4096, 1024),
            nn.LayerNorm(1024),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(1024, 256),
            nn.LayerNorm(256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 64),
            nn.LayerNorm(64),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, num_classes)
        )
        
        vocab_size = len(tokenizer)
        self.decoder = SimpleTransformerDecoder(vocab_size, d_model=768, num_layers=2, nhead=8, 
                                                  dim_feedforward=2048, dropout=0.1, max_len=512)
        self.hidden_size = 768

    def forward(self, front_image, lateral_img, input_ids_caption=None, attention_mask_caption=None, calc_caption_loss=False):
        B = front_image.size(0)
        device = front_image.device

        front_raw = self.encoder_front(front_image)   
        lateral_raw = self.encoder_lateral(lateral_img)  
        combined_raw = torch.cat([front_raw, lateral_raw], dim=-1)  
        classification_logits = self.classifier(combined_raw)
        
        front_proj = self.image_proj(front_raw)         
        lateral_proj = self.image_proj(lateral_raw)        
        image_prefix = torch.stack([front_proj, lateral_proj], dim=1)  

        caption_loss = None
        if calc_caption_loss and input_ids_caption is not None:
            tgt = input_ids_caption
            tgt_emb = self.decoder.embedding(tgt)   
            tgt_emb = tgt_emb.transpose(0, 1)         
            tgt_emb = self.decoder.positional_encoding(tgt_emb)
            memory = image_prefix.transpose(0, 1)    
            tgt_mask = self.decoder.generate_square_subsequent_mask(tgt_emb.size(0)).to(device)
            decoder_output = self.decoder.transformer_decoder(tgt_emb, memory, tgt_mask=tgt_mask)
            decoder_output = decoder_output.transpose(0, 1)  
            logits = self.decoder.fc_out(decoder_output)     
            
            logits = logits[:, :-1, :]
            target = tgt[:, 1:]
            caption_loss = F.cross_entropy(logits.reshape(-1, logits.size(-1)), target.reshape(-1), ignore_index=tokenizer.pad_token_id)
            
        return {
            'classification_logits': classification_logits,
            'caption_loss': caption_loss
        }

    def generate_report(self, front_image, lateral_img, device, max_length=128, top_k=50, temperature=1.0):
        self.eval()
        with torch.no_grad():
            B = front_image.size(0)
            front_raw = self.encoder_front(front_image)
            lateral_raw = self.encoder_lateral(lateral_img)
            front_proj = self.image_proj(front_raw)
            lateral_proj = self.image_proj(lateral_raw)
            memory = torch.stack([front_proj, lateral_proj], dim=1)
            memory = memory.transpose(0, 1)

            bos_token_id = tokenizer.bos_token_id if tokenizer.bos_token_id is not None else tokenizer.eos_token_id
            generated = torch.full((B, 1), bos_token_id, dtype=torch.long, device=device)

            for t in range(max_length - 1):
                tgt_emb = self.decoder.embedding(generated)
                tgt_emb = tgt_emb.transpose(0, 1)
                tgt_emb = self.decoder.positional_encoding(tgt_emb)
                tgt_mask = self.decoder.generate_square_subsequent_mask(tgt_emb.size(0)).to(device)
                decoder_output = self.decoder.transformer_decoder(tgt_emb, memory, tgt_mask=tgt_mask)
                decoder_output = decoder_output.transpose(0, 1)
                logits = self.decoder.fc_out(decoder_output[:, -1, :])
                logits = logits / temperature
                topk_logits, topk_indices = torch.topk(logits, top_k, dim=-1)
                probabilities = F.softmax(topk_logits, dim=-1)
                next_token = topk_indices.gather(-1, torch.multinomial(probabilities, 1))
                generated = torch.cat([generated, next_token], dim=1)
                if (next_token == tokenizer.eos_token_id).all():
                    break
            return generated

print("fine creazione modello AllegroChirurgoModel con decoder semplice (modificato)")
# Out:
# fine creazione modello AllegroChirurgoModel con decoder semplice (modificato)

# %% [markdown]
# # 7

# %%
class WrappedDataLoader:
    def __init__(self, dataloader, shuffle=False, limit_batches=None):
        self.dataloader = dataloader
        self.shuffle = shuffle
        self.address = []
        self.limit_batches = limit_batches
        self.dataset = dataloader.dataset

        batches = iter(self.dataloader)
        for i, b in tqdm(enumerate(batches), 
                         total=len(batches) if limit_batches is None else min(limit_batches, len(batches)), 
                         unit="batch"):
            if self.limit_batches and i >= self.limit_batches:
                break
            self.address.append(b)
        
    def __len__(self):
        return len(self.address)

    def __iter__(self):
        if self.shuffle:
            random.shuffle(self.address)
            return iter(self.address)
        return iter(self.address)

def collate_fn(batch):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    front_pixel_values = torch.stack([item['front_pixel_values'] for item in batch]).to(device)
    lateral_pixel_values = torch.stack([item['lateral_pixel_values'] for item in batch]).to(device)
    input_ids_caption = torch.stack([item['input_ids_caption'] for item in batch]).to(device)
    attention_mask_caption = torch.stack([item['attention_mask_caption'] for item in batch]).to(device)
    zone_categories = torch.stack([item['categories'] for item in batch]).to(device)

    return {
        'front_pixel_values': front_pixel_values,
        'lateral_pixel_values': lateral_pixel_values,
        'input_ids_caption': input_ids_caption,
        'attention_mask_caption': attention_mask_caption,
        'categories': zone_categories
    }

train_loader = DataLoader(
    train_ds,
    batch_size=BATCH_SIZE_DATALOADERS,
    shuffle=True,
    collate_fn=collate_fn
)
train_loader = WrappedDataLoader(train_loader, shuffle=True)

val_loader = DataLoader(
    valid_ds,
    batch_size=BATCH_SIZE_DATALOADERS,
    shuffle=False,
    collate_fn=collate_fn
)
val_loader = WrappedDataLoader(val_loader)

print("fine WrappedDataLoader")
# Out:
# 100%|██████████| 219/219 [05:31<00:00,  1.51s/batch]
# 100%|██████████| 55/55 [01:21<00:00,  1.48s/batch]
# fine WrappedDataLoader

# %% [markdown]
# # 8

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=1.0, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        if isinstance(alpha, (list, np.ndarray)):
            self.alpha = torch.tensor(alpha, dtype=torch.float)
        elif isinstance(alpha, torch.Tensor):
            self.alpha = alpha
        else:
            self.alpha = alpha 
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        if isinstance(self.alpha, torch.Tensor):
            if self.alpha.device != inputs.device:
                self.alpha = self.alpha.to(inputs.device)
            alpha_t = self.alpha[targets]
        else:
            alpha_t = self.alpha
        focal_loss = alpha_t * (1 - pt) ** self.gamma * ce_loss
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
train_labels = train_df['categories'].apply(lambda x: risk_mapping.get(x, 0)).values
classes = np.unique(train_labels)

class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=train_labels)
print("Class weights (compute_class_weight):", class_weights)

normalized_weights = class_weights / np.sum(class_weights) * len(class_weights)
print("Normalized class weights:", normalized_weights)

class_weights_tensor = torch.tensor(normalized_weights, dtype=torch.float).to(device)

focal_loss_fn = FocalLoss(alpha=class_weights_tensor, gamma=2.0, reduction='mean')

def evaluate_validation_loss(model, val_loader, alpha, device, class_weights_tensor):
    model.eval()
    running_total_loss = 0.0
    running_class_loss = 0.0
    running_caption_loss = 0.0
    steps = 0
    
    with torch.no_grad():
        for batch in tqdm(val_loader, total=len(val_loader), leave=False):
            front = batch['front_pixel_values'].to(device, non_blocking=True)
            lat = batch['lateral_pixel_values'].to(device, non_blocking=True)
            ids = batch['input_ids_caption'].to(device, non_blocking=True)
            attn = batch['attention_mask_caption'].to(device, non_blocking=True)
            labels_class = torch.argmax(batch['categories'].to(device, non_blocking=True), dim=1)
            
            outputs = model(
                front_image=front,
                lateral_img=lat,
                input_ids_caption=ids,
                attention_mask_caption=attn,
                calc_caption_loss=True  
            )

            caption_loss = outputs['caption_loss']
            class_logits = outputs['classification_logits']
            class_loss = F.cross_entropy(class_logits, labels_class, weight=class_weights_tensor)
            total_loss = class_loss + alpha * caption_loss
            running_total_loss += total_loss.item()
            running_class_loss += class_loss.item()
            running_caption_loss += caption_loss.item()
            steps += 1

    avg_total = running_total_loss / steps if steps > 0 else 0
    avg_class = running_class_loss / steps if steps > 0 else 0
    avg_caption = running_caption_loss / steps if steps > 0 else 0
    return avg_total, avg_class, avg_caption

def train_model(model, train_loader, val_loader, optimizer, device, alpha=1.0, num_epochs=5, early_stopping_patience=3, class_weights_tensor=None):
    history = []
    model = model.to(device)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)
    best_val_loss = float('inf')
    epochs_without_improve = 0

    for epoch in range(num_epochs):
        model.train()
        running_total_loss = 0.0
        running_class_loss = 0.0
        running_caption_loss = 0.0
        steps = 0

        progress_bar = tqdm(train_loader, total=len(train_loader), desc=f'Epoch {epoch+1}/{num_epochs}')

        for batch in progress_bar:
            front = batch['front_pixel_values'].to(device)
            lat   = batch['lateral_pixel_values'].to(device)
            ids   = batch['input_ids_caption'].to(device)
            attn  = batch['attention_mask_caption'].to(device)
            labels_class = torch.argmax(batch['categories'].to(device), dim=1)

            optimizer.zero_grad()
            outputs = model(
                front,
                lat,
                input_ids_caption=ids,
                attention_mask_caption=attn,
                calc_caption_loss=True 
            )
            
            caption_loss = outputs['caption_loss']
            class_logits = outputs['classification_logits']
            class_loss = focal_loss_fn(class_logits, labels_class) if FOCAL_LOSS else F.cross_entropy(class_logits, labels_class, weight=class_weights_tensor)
            total_loss = class_loss + alpha * caption_loss
            total_loss.backward()
            optimizer.step()

            running_total_loss += total_loss.item()
            running_class_loss += class_loss.item()
            running_caption_loss += caption_loss.item()
            steps += 1

        avg_train_total = running_total_loss / steps if steps > 0 else 0
        avg_train_class = running_class_loss / steps if steps > 0 else 0
        avg_train_caption = running_caption_loss / steps if steps > 0 else 0

        val_total, val_class, val_caption = evaluate_validation_loss(model, val_loader, alpha, device, class_weights_tensor)
        history.append((avg_train_total, val_total))
        
        scheduler.step(val_total)

        print(f"Train: Total={avg_train_total:.4f}, Class={avg_train_class:.4f}, Caption={avg_train_caption:.4f} | "
              f"Val: Total={val_total:.4f}, Class={val_class:.4f}, Caption={val_caption:.4f}")

        if val_total < best_val_loss:
            best_val_loss = val_total
            epochs_without_improve = 0
        else:
            epochs_without_improve += 1
            if epochs_without_improve >= early_stopping_patience:
                print(f"Early stopping activated. No improvement in validation loss for {early_stopping_patience} epochs.")
                break

    return history

model = AllegroChirurgoModel(num_classes=num_class_pred, teacher_forcing_rate=TEACHER_FORCING_RATE)
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

save_directory = "./saved_model"

if TRAIN_MAIN_MODEL:
    train_history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        optimizer=optimizer,
        device=device,
        alpha=ALPHA_MAIN_MODEL,
        num_epochs=NUM_EPOCHS_MAIN_MODEL,
        early_stopping_patience=EARLY_STOPPING_PATIENCE,
        class_weights_tensor=class_weights_tensor
    )

    os.makedirs(MODEL_SAVE_DIR, exist_ok=True)
    torch.save(model.state_dict(), MAIN_MODEL_PATH)
    tokenizer.save_pretrained(MODEL_SAVE_DIR)
    print(f"Model and tokenizer saved to {MODEL_SAVE_DIR}")
    
else:
    model.load_state_dict(torch.load(MAIN_MODEL_PATH, map_location=device))

print("fine TRAIN_MAIN_MODEL")
# Out:
# Class weights (compute_class_weight): [0.53282443 0.8835443  8.30952381 2.32666667 0.69383698]
# Normalized class weights: [0.20900983 0.34658593 3.25955811 0.91267627 0.27216986]
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 211MB/s]
# Epoch 1/10: 100%|██████████| 219/219 [01:08<00:00,  3.18it/s]
# Train: Total=1.9802, Class=0.4320, Caption=3.8704 | Val: Total=2.5496, Class=1.6342, Caption=2.2886
# Epoch 2/10: 100%|██████████| 219/219 [01:07<00:00,  3.23it/s]
# Train: Total=1.2229, Class=0.4202, Caption=2.0067 | Val: Total=2.2937, Class=1.5725, Caption=1.8030
# Epoch 3/10: 100%|██████████| 219/219 [01:07<00:00,  3.23it/s]
# Train: Total=1.0545, Class=0.4007, Caption=1.6345 | Val: Total=2.2054, Class=1.5613, Caption=1.6104
# Epoch 4/10: 100%|██████████| 219/219 [01:07<00:00,  3.23it/s]
# Train: Total=0.9647, Class=0.3944, Caption=1.4258 | Val: Total=2.1445, Class=1.5489, Caption=1.4890
# Epoch 5/10: 100%|██████████| 219/219 [01:07<00:00,  3.23it/s]
# Train: Total=0.8999, Class=0.3882, Caption=1.2793 | Val: Total=2.1671, Class=1.6052, Caption=1.4048
# Epoch 6/10: 100%|██████████| 219/219 [01:07<00:00,  3.23it/s]
# Train: Total=0.8611, Class=0.3958, Caption=1.1631 | Val: Total=2.1326, Class=1.5881, Caption=1.3614
# Epoch 7/10: 100%|██████████| 219/219 [01:07<00:00,  3.23it/s]
# Train: Total=0.8035, Class=0.3772, Caption=1.0659 | Val: Total=2.0757, Class=1.5455, Caption=1.3254
# Epoch 8/10: 100%|██████████| 219/219 [01:07<00:00,  3.24it/s]
# Train: Total=0.7647, Class=0.3715, Caption=0.9830 | Val: Total=2.0662, Class=1.5474, Caption=1.2970
# Epoch 9/10: 100%|██████████| 219/219 [01:07<00:00,  3.24it/s]
# Train: Total=0.7421, Class=0.3790, Caption=0.9079 | Val: Total=2.0660, Class=1.5505, Caption=1.2888
# Epoch 10/10: 100%|██████████| 219/219 [01:07<00:00,  3.23it/s]
# Train: Total=0.6927, Class=0.3585, Caption=0.8356 | Val: Total=2.1032, Class=1.5932, Caption=1.2749
# Model and tokenizer saved to ./saved_model
# fine TRAIN_MAIN_MODEL

# %%
test_loader = DataLoader(
    test_ds,
    batch_size=BATCH_SIZE_DATALOADERS,
    collate_fn=collate_fn
)
test_loader = WrappedDataLoader(test_loader)

warnings.filterwarnings("ignore", category=UserWarning, module="transformers")
logging.getLogger("transformers").setLevel(logging.ERROR)

def calculate_bleu(pred_ids, ref_ids, tokenizer):
    pred_tokens = tokenizer.convert_ids_to_tokens(pred_ids)
    ref_tokens = tokenizer.convert_ids_to_tokens(ref_ids)

    if not pred_tokens or not ref_tokens:
        return (0.0, 0.0, 0.0, 0.0)

    smoothing = SmoothingFunction().method1
    bleu1 = sentence_bleu([ref_tokens], pred_tokens, weights=(1, 0, 0, 0), smoothing_function=smoothing)
    bleu2 = sentence_bleu([ref_tokens], pred_tokens, weights=(0.5, 0.5, 0, 0), smoothing_function=smoothing)
    bleu3 = sentence_bleu([ref_tokens], pred_tokens, weights=(0.33, 0.33, 0.33, 0), smoothing_function=smoothing)
    bleu4 = sentence_bleu([ref_tokens], pred_tokens, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=smoothing)

    return bleu1, bleu2, bleu3, bleu4

def calculate_rouge_l(predicted_text, reference_text):
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    score = scorer.score(reference_text, predicted_text)
    return score['rougeL'].fmeasure

def test_model(model, test_loader, tokenizer):
    model.eval()
    total_bleu1 = total_bleu2 = total_bleu3 = total_bleu4 = 0
    total_rouge_l = 0

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Testing"):
            gen_ids = model.generate_report(
                front_image=batch['front_pixel_values'],
                lateral_img=batch['lateral_pixel_values'],
                device=device,
                temperature=1.0,
                top_k=50
            )

            for pred_ids, ref_ids in zip(gen_ids, batch['input_ids_caption']):
                bleu1, bleu2, bleu3, bleu4 = calculate_bleu(pred_ids.tolist(), ref_ids.tolist(), tokenizer)
                total_bleu1 += bleu1
                total_bleu2 += bleu2
                total_bleu3 += bleu3
                total_bleu4 += bleu4

                predicted_text = tokenizer.decode(pred_ids.tolist(), skip_special_tokens=True)
                reference_text = tokenizer.decode(ref_ids.tolist(), skip_special_tokens=True)
                rouge_l_score = calculate_rouge_l(predicted_text, reference_text)
                total_rouge_l += rouge_l_score

    dataset_size = len(test_loader.dataset)
    metrics = {
        'bleu1': total_bleu1 / dataset_size,
        'bleu2': total_bleu2 / dataset_size,
        'bleu3': total_bleu3 / dataset_size,
        'bleu4': total_bleu4 / dataset_size,
        'rouge_l': total_rouge_l / dataset_size
    }

    print("\nTest Results:")
    print(f"BLEU-1 Score: {metrics['bleu1']:.4f}")
    print(f"BLEU-2 Score: {metrics['bleu2']:.4f}")
    print(f"BLEU-3 Score: {metrics['bleu3']:.4f}")
    print(f"BLEU-4 Score: {metrics['bleu4']:.4f}")
    print(f"ROUGE-L Score: {metrics['rouge_l']:.4f}")

    return metrics

def visualize_predictions(model, test_loader, tokenizer, num_images=2):
    import matplotlib.pyplot as plt
    model.eval()
    visualizations_shown = 0

    with torch.no_grad():
        for batch in test_loader:
            gen_ids = model.generate_report(
                front_image=batch['front_pixel_values'],
                lateral_img=batch['lateral_pixel_values'],
                device=device,
                temperature=1.0,
                top_k=50
            )

            for i in range(len(gen_ids)):
                if visualizations_shown >= num_images:
                    return

                pred_caption = tokenizer.decode(gen_ids[i].tolist(), skip_special_tokens=True)
                true_caption = tokenizer.decode(batch['input_ids_caption'][i].tolist(), skip_special_tokens=True)
                
                plt.figure(figsize=(10, 5))

                plt.subplot(1, 2, 1)
                plt.imshow(batch['front_pixel_values'][i].cpu().permute(1, 2, 0))
                plt.axis('off')
                plt.title('Frontal View')

                plt.subplot(1, 2, 2)
                plt.imshow(batch['lateral_pixel_values'][i].cpu().permute(1, 2, 0))
                plt.axis('off')
                plt.title('Lateral View')

                plt.show()
                print(f"True Caption: {true_caption}")
                print(f"Pred Caption: {pred_caption}")
                print('-' * 50)

                visualizations_shown += 1

metrics = test_model(model, test_loader, tokenizer)
visualize_predictions(model, test_loader, tokenizer, num_images=1)


def evaluate_predictions_full(model, val_loader, num_class_pred=num_class_pred):
    import torch
    import numpy as np
    from sklearn.metrics import confusion_matrix
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.eval()
    correct_predictions = 0
    total_predictions = 0
    class_correct = torch.zeros(num_class_pred, dtype=torch.int32)
    class_total = torch.zeros(num_class_pred, dtype=torch.int32)
    all_predictions = []
    
    with torch.no_grad():
        for batch in val_loader:
            front_image = batch['front_pixel_values']
            lateral_image = batch['lateral_pixel_values']
            labels = torch.argmax(batch['categories'], dim=1)
            
            outputs = model(
                front_image=front_image,
                lateral_img=lateral_image,
                input_ids_caption=batch['input_ids_caption'],
                attention_mask_caption=batch['attention_mask_caption'],
            )
            logits = outputs["classification_logits"]
            predicted_labels = torch.argmax(logits, dim=1)

            for true_label, pred_label in zip(labels.tolist(), predicted_labels.tolist()):
                all_predictions.append((true_label, pred_label))
            
            correct_predictions += (predicted_labels == labels).sum().item()
            total_predictions += labels.size(0)
            
            for class_label in range(num_class_pred):
                class_correct[class_label] += ((predicted_labels == class_label) &
                                               (labels == class_label)).sum().item()
                class_total[class_label] += (labels == class_label).sum().item()
    
    accuracy = 100.0 * correct_predictions / total_predictions
    print(f"Accuracy su tutto il set di validazione: {accuracy:.2f}%")
    
    print("\nAccuratezze per classe:")
    for class_label in range(num_class_pred):
        if class_total[class_label] > 0:
            class_accuracy = 100.0 * class_correct[class_label] / class_total[class_label]
            print(f"Classe {class_label}: {class_accuracy:.2f}% "
                  f"({class_correct[class_label]}/{class_total[class_label]})")
        else:
            print(f"Classe {class_label}: Nessun campione presente.")
    
    print("\nDettagli predizioni:")
    for i, (true_label, pred_label) in enumerate(all_predictions):
        print(f"Campione {i + 1}: Classe vera = {true_label}, Classe predetta = {pred_label}")

    return accuracy

accuracy = evaluate_predictions_full(model, test_loader)
print(f"Accuracy Finale: {accuracy:.2f}%")



print("fine evaluate predictions full e text loss")
# Out:
# 100%|██████████| 69/69 [01:40<00:00,  1.45s/batch]
# Testing: 100%|██████████| 69/69 [00:47<00:00,  1.44it/s]
# Test Results:
# BLEU-1 Score: 0.2019
# BLEU-2 Score: 0.1407
# BLEU-3 Score: 0.1039
# BLEU-4 Score: 0.0735
# ROUGE-L Score: 0.1790
# True Caption: Heart size and pulmonary vascularity appear within normal limits. Descending thoracic aorta is tortuous. Lungs are free of focal airspace disease. No pleural effusion or pneumothorax is seen. Degenerative changes are present in the spine.
# Pred Caption:  heart size and pulmonary vascularity appear within normal limits. The lungs are free of focal airspace disease. No pleural effusion or pneumothorax is seen. Degenerative changes are present within the spine. Dextroscoliosis and thoracic spine fusion appear intact. Degenerative changes are present in the spine. The thoracic aorta is present. The bony structures of thoracic spine and upper limit vertebral body XXXX is present in XXXX spine. Degenerative changes are demonstrate thoracic spine. V XXXX. There are unremarkable. There is again again noted.
# --------------------------------------------------
# Accuracy su tutto il set di validazione: 34.62%
#
# Accuratezze per classe:
# Classe 0: 63.90% (131/205)
# Classe 1: 17.74% (22/124)
# Classe 2: 15.38% (2/13)
# Classe 3: 8.51% (4/47)
# Classe 4: 19.11% (30/157)
#
# Dettagli predizioni:
# Campione 1: Classe vera = 3, Classe predetta = 1
# Campione 2: Classe vera = 1, Classe predetta = 0
# Campione 3: Classe vera = 0, Classe predetta = 3
# Campione 4: Classe vera = 4, Classe predetta = 2
# Campione 5: Classe vera = 0, Classe predetta = 0
# Campione 6: Classe vera = 4, Classe predetta = 0
# Campione 7: Classe vera = 0, Classe predetta = 0
# Campione 8: Classe vera = 3, Classe predetta = 1
# Campione 9: Classe vera = 0, Classe predetta = 4
# Campione 10: Classe vera = 1, Classe predetta = 4
# Campione 11: Classe vera = 0, Classe predetta = 1
# Campione 12: Classe vera = 0, Classe predetta = 0
# Campione 13: Classe vera = 4, Classe predetta = 2
# Campione 14: Classe vera = 0, Classe predetta = 0
# Campione 15: Classe vera = 4, Classe predetta = 2
# Campione 16: Classe vera = 4, Classe predetta = 2
# Campione 17: Classe vera = 1, Classe predetta = 0
# Campione 18: Classe vera = 0, Classe predetta = 0
# Campione 19: Classe vera = 0, Classe predetta = 0
# Campione 20: Classe vera = 4, Classe predetta = 4
# Campione 21: Classe vera = 4, Classe predetta = 3
# Campione 22: Classe vera = 3, Classe predetta = 0
# Campione 23: Classe vera = 4, Classe predetta = 2
# Campione 24: Classe vera = 1, Classe predetta = 0
# Campione 25: Classe vera = 0, Classe predetta = 0
# Campione 26: Classe vera = 0, Classe predetta = 2
# Campione 27: Classe vera = 1, Classe predetta = 4
# Campione 28: Classe vera = 0, Classe predetta = 0
# Campione 29: Classe vera = 1, Classe predetta = 1
# Campione 30: Classe vera = 0, Classe predetta = 0
# Campione 31: Classe vera = 4, Classe predetta = 4
# Campione 32: Classe vera = 2, Classe predetta = 2
# Campione 33: Classe vera = 2, Classe predetta = 0
# Campione 34: Classe vera = 0, Classe predetta = 4
# Campione 35: Classe vera = 4, Classe predetta = 3
# Campione 36: Classe vera = 0, Classe predetta = 0
# Campione 37: Classe vera = 3, Classe predetta = 4
# Campione 38: Classe vera = 3, Classe predetta = 1
# Campione 39: Classe vera = 0, Classe predetta = 0
# Campione 40: Classe vera = 3, Classe predetta = 0
# Campione 41: Classe vera = 4, Classe predetta = 2
# Campione 42: Classe vera = 0, Classe predetta = 4
# Campione 43: Classe vera = 1, Classe predetta = 0
# Campione 44: Classe vera = 0, Classe predetta = 1
# Campione 45: Classe vera = 4, Classe predetta = 4
# Campione 46: Classe vera = 0, Classe predetta = 1
# Campione 47: Classe vera = 1, Classe predetta = 0
# Campione 48: Classe vera = 1, Classe predetta = 0
# Campione 49: Classe vera = 1, Classe predetta = 1
# Campione 50: Classe vera = 0, Classe predetta = 1
# Campione 51: Classe vera = 0, Classe predetta = 0
# Campione 52: Classe vera = 4, Classe predetta = 2
# Campione 53: Classe vera = 4, Classe predetta = 3
# Campione 54: Classe vera = 0, Classe predetta = 2
# Campione 55: Classe vera = 1, Classe predetta = 4
# Campione 56: Classe vera = 4, Classe predetta = 0
# Campione 57: Classe vera = 4, Classe predetta = 1
# Campione 58: Classe vera = 1, Classe predetta = 0
# Campione 59: Classe vera = 0, Classe predetta = 0
# Campione 60: Classe vera = 4, Classe predetta = 0
# Campione 61: Classe vera = 4, Classe predetta = 4
# Campione 62: Classe vera = 1, Classe predetta = 0
# Campione 63: Classe vera = 0, Classe predetta = 1
# Campione 64: Classe vera = 0, Classe predetta = 0
# Campione 65: Classe vera = 1, Classe predetta = 4
# Campione 66: Classe vera = 1, Classe predetta = 1
# Campione 67: Classe vera = 3, Classe predetta = 1
# Campione 68: Classe vera = 0, Classe predetta = 4
# Campione 69: Classe vera = 4, Classe predetta = 3
# Campione 70: Classe vera = 1, Classe predetta = 4
# Campione 71: Classe vera = 4, Classe predetta = 3
# Campione 72: Classe vera = 4, Classe predetta = 1
# Campione 73: Classe vera = 1, Classe predetta = 0
# Campione 74: Classe vera = 4, Classe predetta = 2
# Campione 75: Classe vera = 1, Classe predetta = 1
# Campione 76: Classe vera = 4, Classe predetta = 3
# Campione 77: Classe vera = 2, Classe predetta = 1
# Campione 78: Classe vera = 4, Classe predetta = 3
# Campione 79: Classe vera = 1, Classe predetta = 4
# Campione 80: Classe vera = 4, Classe predetta = 1
# Campione 81: Classe vera = 0, Classe predetta = 0
# Campione 82: Classe vera = 0, Classe predetta = 0
# Campione 83: Classe vera = 0, Classe predetta = 0
# Campione 84: Classe vera = 1, Classe predetta = 4
# Campione 85: Classe vera = 4, Classe predetta = 1
# Campione 86: Classe vera = 4, Classe predetta = 2
# Campione 87: Classe vera = 0, Classe predetta = 0
# Campione 88: Classe vera = 0, Classe predetta = 1
# Campione 89: Classe vera = 4, Classe predetta = 1
# Campione 90: Classe vera = 3, Classe predetta = 4
# Campione 91: Classe vera = 0, Classe predetta = 0
# Campione 92: Classe vera = 0, Classe predetta = 0
# Campione 93: Classe vera = 0, Classe predetta = 0
# Campione 94: Classe vera = 3, Classe predetta = 0
# Campione 95: Classe vera = 4, Classe predetta = 2
# Campione 96: Classe vera = 4, Classe predetta = 4
# Campione 97: Classe vera = 4, Classe predetta = 1
# Campione 98: Classe vera = 4, Classe predetta = 3
# Campione 99: Classe vera = 4, Classe predetta = 3
# Campione 100: Classe vera = 0, Classe predetta = 0
# Campione 101: Classe vera = 3, Classe predetta = 0
# Campione 102: Classe vera = 0, Classe predetta = 0
# Campione 103: Classe vera = 0, Classe predetta = 4
# Campione 104: Classe vera = 1, Classe predetta = 4
# Campione 105: Classe vera = 4, Classe predetta = 0
# Campione 106: Classe vera = 4, Classe predetta = 4
# Campione 107: Classe vera = 0, Classe predetta = 0
# Campione 108: Classe vera = 4, Classe predetta = 2
# Campione 109: Classe vera = 4, Classe predetta = 2
# Campione 110: Classe vera = 0, Classe predetta = 4
# Campione 111: Classe vera = 0, Classe predetta = 0
# Campione 112: Classe vera = 0, Classe predetta = 1
# Campione 113: Classe vera = 4, Classe predetta = 4
# Campione 114: Classe vera = 1, Classe predetta = 0
# Campione 115: Classe vera = 4, Classe predetta = 0
# Campione 116: Classe vera = 0, Classe predetta = 1
# Campione 117: Classe vera = 0, Classe predetta = 0
# Campione 118: Classe vera = 4, Classe predetta = 2
# Campione 119: Classe vera = 0, Classe predetta = 0
# Campione 120: Classe vera = 0, Classe predetta = 0
# Campione 121: Classe vera = 1, Classe predetta = 2
# Campione 122: Classe vera = 0, Classe predetta = 1
# Campione 123: Classe vera = 1, Classe predetta = 2
# Campione 124: Classe vera = 0, Classe predetta = 0
# Campione 125: Classe vera = 4, Classe predetta = 0
# Campione 126: Classe vera = 1, Classe predetta = 1
# Campione 127: Classe vera = 1, Classe predetta = 2
# Campione 128: Classe vera = 4, Classe predetta = 0
# Campione 129: Classe vera = 0, Classe predetta = 0
# Campione 130: Classe vera = 0, Classe predetta = 0
# Campione 131: Classe vera = 4, Classe predetta = 2
# Campione 132: Classe vera = 0, Classe predetta = 0
# Campione 133: Classe vera = 1, Classe predetta = 4
# Campione 134: Classe vera = 1, Classe predetta = 2
# Campione 135: Classe vera = 0, Classe predetta = 1
# Campione 136: Classe vera = 4, Classe predetta = 0
# Campione 137: Classe vera = 0, Classe predetta = 4
# Campione 138: Classe vera = 1, Classe predetta = 0
# Campione 139: Classe vera = 0, Classe predetta = 0
# Campione 140: Classe vera = 4, Classe predetta = 0
# Campione 141: Classe vera = 4, Classe predetta = 4
# Campione 142: Classe vera = 0, Classe predetta = 0
# Campione 143: Classe vera = 0, Classe predetta = 2
# Campione 144: Classe vera = 4, Classe predetta = 4
# Campione 145: Classe vera = 4, Classe predetta = 1
# Campione 146: Classe vera = 0, Classe predetta = 1
# Campione 147: Classe vera = 0, Classe predetta = 1
# Campione 148: Classe vera = 4, Classe predetta = 0
# Campione 149: Classe vera = 1, Classe predetta = 0
# Campione 150: Classe vera = 4, Classe predetta = 2
# Campione 151: Classe vera = 4, Classe predetta = 2
# Campione 152: Classe vera = 0, Classe predetta = 1
# Campione 153: Classe vera = 0, Classe predetta = 0
# Campione 154: Classe vera = 4, Classe predetta = 3
# Campione 155: Classe vera = 0, Classe predetta = 3
# Campione 156: Classe vera = 0, Classe predetta = 0
# Campione 157: Classe vera = 4, Classe predetta = 2
# Campione 158: Classe vera = 4, Classe predetta = 2
# Campione 159: Classe vera = 1, Classe predetta = 0
# Campione 160: Classe vera = 4, Classe predetta = 0
# Campione 161: Classe vera = 3, Classe predetta = 1
# Campione 162: Classe vera = 0, Classe predetta = 0
# Campione 163: Classe vera = 4, Classe predetta = 1
# Campione 164: Classe vera = 4, Classe predetta = 0
# Campione 165: Classe vera = 1, Classe predetta = 1
# Campione 166: Classe vera = 0, Classe predetta = 0
# Campione 167: Classe vera = 0, Classe predetta = 2
# Campione 168: Classe vera = 4, Classe predetta = 0
# Campione 169: Classe vera = 1, Classe predetta = 0
# Campione 170: Classe vera = 1, Classe predetta = 4
# Campione 171: Classe vera = 3, Classe predetta = 3
# Campione 172: Classe vera = 3, Classe predetta = 0
# Campione 173: Classe vera = 4, Classe predetta = 4
# Campione 174: Classe vera = 0, Classe predetta = 0
# Campione 175: Classe vera = 4, Classe predetta = 0
# Campione 176: Classe vera = 0, Classe predetta = 0
# Campione 177: Classe vera = 0, Classe predetta = 0
# Campione 178: Classe vera = 0, Classe predetta = 0
# Campione 179: Classe vera = 4, Classe predetta = 2
# Campione 180: Classe vera = 4, Classe predetta = 0
# Campione 181: Classe vera = 1, Classe predetta = 3
# Campione 182: Classe vera = 0, Classe predetta = 0
# Campione 183: Classe vera = 3, Classe predetta = 0
# Campione 184: Classe vera = 0, Classe predetta = 0
# Campione 185: Classe vera = 2, Classe predetta = 1
# Campione 186: Classe vera = 4, Classe predetta = 2
# Campione 187: Classe vera = 4, Classe predetta = 2
# Campione 188: Classe vera = 4, Classe predetta = 2
# Campione 189: Classe vera = 0, Classe predetta = 2
# Campione 190: Classe vera = 0, Classe predetta = 1
# Campione 191: Classe vera = 0, Classe predetta = 0
# Campione 192: Classe vera = 4, Classe predetta = 0
# Campione 193: Classe vera = 4, Classe predetta = 3
# Campione 194: Classe vera = 4, Classe predetta = 1
# Campione 195: Classe vera = 0, Classe predetta = 2
# Campione 196: Classe vera = 1, Classe predetta = 0
# Campione 197: Classe vera = 0, Classe predetta = 2
# Campione 198: Classe vera = 1, Classe predetta = 3
# Campione 199: Classe vera = 4, Classe predetta = 1
# Campione 200: Classe vera = 1, Classe predetta = 2
# Campione 201: Classe vera = 0, Classe predetta = 1
# Campione 202: Classe vera = 4, Classe predetta = 2
# Campione 203: Classe vera = 0, Classe predetta = 2
# Campione 204: Classe vera = 1, Classe predetta = 0
# Campione 205: Classe vera = 3, Classe predetta = 0
# Campione 206: Classe vera = 4, Classe predetta = 2
# Campione 207: Classe vera = 3, Classe predetta = 0
# Campione 208: Classe vera = 0, Classe predetta = 1
# Campione 209: Classe vera = 1, Classe predetta = 2
# Campione 210: Classe vera = 0, Classe predetta = 0
# Campione 211: Classe vera = 1, Classe predetta = 2
# Campione 212: Classe vera = 4, Classe predetta = 2
# Campione 213: Classe vera = 0, Classe predetta = 0
# Campione 214: Classe vera = 1, Classe predetta = 0
# Campione 215: Classe vera = 3, Classe predetta = 2
# Campione 216: Classe vera = 0, Classe predetta = 0
# Campione 217: Classe vera = 4, Classe predetta = 1
# Campione 218: Classe vera = 1, Classe predetta = 4
# Campione 219: Classe vera = 3, Classe predetta = 0
# Campione 220: Classe vera = 0, Classe predetta = 2
# Campione 221: Classe vera = 4, Classe predetta = 2
# Campione 222: Classe vera = 1, Classe predetta = 2
# Campione 223: Classe vera = 0, Classe predetta = 4
# Campione 224: Classe vera = 1, Classe predetta = 1
# Campione 225: Classe vera = 0, Classe predetta = 1
# Campione 226: Classe vera = 1, Classe predetta = 2
# Campione 227: Classe vera = 4, Classe predetta = 0
# Campione 228: Classe vera = 1, Classe predetta = 1
# Campione 229: Classe vera = 0, Classe predetta = 0
# Campione 230: Classe vera = 4, Classe predetta = 0
# Campione 231: Classe vera = 4, Classe predetta = 2
# Campione 232: Classe vera = 3, Classe predetta = 1
# Campione 233: Classe vera = 0, Classe predetta = 0
# Campione 234: Classe vera = 0, Classe predetta = 0
# Campione 235: Classe vera = 4, Classe predetta = 4
# Campione 236: Classe vera = 4, Classe predetta = 2
# Campione 237: Classe vera = 4, Classe predetta = 3
# Campione 238: Classe vera = 4, Classe predetta = 3
# Campione 239: Classe vera = 0, Classe predetta = 0
# Campione 240: Classe vera = 4, Classe predetta = 0
# Campione 241: Classe vera = 0, Classe predetta = 0
# Campione 242: Classe vera = 4, Classe predetta = 4
# Campione 243: Classe vera = 0, Classe predetta = 2
# Campione 244: Classe vera = 2, Classe predetta = 0
# Campione 245: Classe vera = 4, Classe predetta = 2
# Campione 246: Classe vera = 2, Classe predetta = 0
# Campione 247: Classe vera = 1, Classe predetta = 4
# Campione 248: Classe vera = 0, Classe predetta = 0
# Campione 249: Classe vera = 0, Classe predetta = 0
# Campione 250: Classe vera = 0, Classe predetta = 0
# Campione 251: Classe vera = 1, Classe predetta = 0
# Campione 252: Classe vera = 2, Classe predetta = 0
# Campione 253: Classe vera = 1, Classe predetta = 0
# Campione 254: Classe vera = 0, Classe predetta = 0
# Campione 255: Classe vera = 1, Classe predetta = 0
# Campione 256: Classe vera = 0, Classe predetta = 0
# Campione 257: Classe vera = 3, Classe predetta = 0
# Campione 258: Classe vera = 0, Classe predetta = 0
# Campione 259: Classe vera = 4, Classe predetta = 0
# Campione 260: Classe vera = 1, Classe predetta = 2
# Campione 261: Classe vera = 3, Classe predetta = 2
# Campione 262: Classe vera = 4, Classe predetta = 4
# Campione 263: Classe vera = 0, Classe predetta = 2
# Campione 264: Classe vera = 0, Classe predetta = 0
# Campione 265: Classe vera = 4, Classe predetta = 1
# Campione 266: Classe vera = 1, Classe predetta = 4
# Campione 267: Classe vera = 0, Classe predetta = 0
# Campione 268: Classe vera = 0, Classe predetta = 0
# Campione 269: Classe vera = 0, Classe predetta = 0
# Campione 270: Classe vera = 0, Classe predetta = 3
# Campione 271: Classe vera = 1, Classe predetta = 4
# Campione 272: Classe vera = 0, Classe predetta = 2
# Campione 273: Classe vera = 0, Classe predetta = 0
# Campione 274: Classe vera = 1, Classe predetta = 2
# Campione 275: Classe vera = 4, Classe predetta = 2
# Campione 276: Classe vera = 0, Classe predetta = 0
# Campione 277: Classe vera = 4, Classe predetta = 4
# Campione 278: Classe vera = 4, Classe predetta = 1
# Campione 279: Classe vera = 1, Classe predetta = 3
# Campione 280: Classe vera = 4, Classe predetta = 2
# Campione 281: Classe vera = 4, Classe predetta = 3
# Campione 282: Classe vera = 4, Classe predetta = 0
# Campione 283: Classe vera = 1, Classe predetta = 0
# Campione 284: Classe vera = 4, Classe predetta = 4
# Campione 285: Classe vera = 4, Classe predetta = 2
# Campione 286: Classe vera = 0, Classe predetta = 0
# Campione 287: Classe vera = 4, Classe predetta = 0
# Campione 288: Classe vera = 1, Classe predetta = 0
# Campione 289: Classe vera = 1, Classe predetta = 0
# Campione 290: Classe vera = 0, Classe predetta = 2
# Campione 291: Classe vera = 1, Classe predetta = 3
# Campione 292: Classe vera = 0, Classe predetta = 0
# Campione 293: Classe vera = 4, Classe predetta = 2
# Campione 294: Classe vera = 3, Classe predetta = 4
# Campione 295: Classe vera = 0, Classe predetta = 0
# Campione 296: Classe vera = 0, Classe predetta = 1
# Campione 297: Classe vera = 3, Classe predetta = 4
# Campione 298: Classe vera = 0, Classe predetta = 1
# Campione 299: Classe vera = 0, Classe predetta = 2
# Campione 300: Classe vera = 4, Classe predetta = 2
# Campione 301: Classe vera = 1, Classe predetta = 0
# Campione 302: Classe vera = 1, Classe predetta = 4
# Campione 303: Classe vera = 0, Classe predetta = 0
# Campione 304: Classe vera = 4, Classe predetta = 2
# Campione 305: Classe vera = 0, Classe predetta = 1
# Campione 306: Classe vera = 2, Classe predetta = 2
# Campione 307: Classe vera = 3, Classe predetta = 4
# Campione 308: Classe vera = 3, Classe predetta = 2
# Campione 309: Classe vera = 0, Classe predetta = 0
# Campione 310: Classe vera = 0, Classe predetta = 0
# Campione 311: Classe vera = 1, Classe predetta = 0
# Campione 312: Classe vera = 1, Classe predetta = 1
# Campione 313: Classe vera = 0, Classe predetta = 0
# Campione 314: Classe vera = 4, Classe predetta = 1
# Campione 315: Classe vera = 0, Classe predetta = 0
# Campione 316: Classe vera = 0, Classe predetta = 0
# Campione 317: Classe vera = 4, Classe predetta = 2
# Campione 318: Classe vera = 1, Classe predetta = 0
# Campione 319: Classe vera = 4, Classe predetta = 1
# Campione 320: Classe vera = 1, Classe predetta = 2
# Campione 321: Classe vera = 4, Classe predetta = 4
# Campione 322: Classe vera = 1, Classe predetta = 2
# Campione 323: Classe vera = 0, Classe predetta = 1
# Campione 324: Classe vera = 1, Classe predetta = 2
# Campione 325: Classe vera = 4, Classe predetta = 2
# Campione 326: Classe vera = 4, Classe predetta = 0
# Campione 327: Classe vera = 4, Classe predetta = 2
# Campione 328: Classe vera = 3, Classe predetta = 1
# Campione 329: Classe vera = 0, Classe predetta = 0
# Campione 330: Classe vera = 1, Classe predetta = 2
# Campione 331: Classe vera = 0, Classe predetta = 0
# Campione 332: Classe vera = 0, Classe predetta = 0
# Campione 333: Classe vera = 1, Classe predetta = 0
# Campione 334: Classe vera = 1, Classe predetta = 1
# Campione 335: Classe vera = 1, Classe predetta = 0
# Campione 336: Classe vera = 4, Classe predetta = 4
# Campione 337: Classe vera = 4, Classe predetta = 0
# Campione 338: Classe vera = 1, Classe predetta = 1
# Campione 339: Classe vera = 3, Classe predetta = 1
# Campione 340: Classe vera = 1, Classe predetta = 1
# Campione 341: Classe vera = 3, Classe predetta = 3
# Campione 342: Classe vera = 4, Classe predetta = 2
# Campione 343: Classe vera = 4, Classe predetta = 2
# Campione 344: Classe vera = 0, Classe predetta = 0
# Campione 345: Classe vera = 4, Classe predetta = 1
# Campione 346: Classe vera = 0, Classe predetta = 0
# Campione 347: Classe vera = 4, Classe predetta = 0
# Campione 348: Classe vera = 0, Classe predetta = 4
# Campione 349: Classe vera = 0, Classe predetta = 0
# Campione 350: Classe vera = 1, Classe predetta = 1
# Campione 351: Classe vera = 4, Classe predetta = 0
# Campione 352: Classe vera = 1, Classe predetta = 0
# Campione 353: Classe vera = 1, Classe predetta = 0
# Campione 354: Classe vera = 4, Classe predetta = 1
# Campione 355: Classe vera = 1, Classe predetta = 0
# Campione 356: Classe vera = 0, Classe predetta = 0
# Campione 357: Classe vera = 0, Classe predetta = 0
# Campione 358: Classe vera = 1, Classe predetta = 0
# Campione 359: Classe vera = 4, Classe predetta = 1
# Campione 360: Classe vera = 0, Classe predetta = 0
# Campione 361: Classe vera = 1, Classe predetta = 0
# Campione 362: Classe vera = 4, Classe predetta = 4
# Campione 363: Classe vera = 4, Classe predetta = 1
# Campione 364: Classe vera = 0, Classe predetta = 3
# Campione 365: Classe vera = 4, Classe predetta = 2
# Campione 366: Classe vera = 1, Classe predetta = 4
# Campione 367: Classe vera = 0, Classe predetta = 0
# Campione 368: Classe vera = 2, Classe predetta = 0
# Campione 369: Classe vera = 1, Classe predetta = 2
# Campione 370: Classe vera = 2, Classe predetta = 1
# Campione 371: Classe vera = 0, Classe predetta = 1
# Campione 372: Classe vera = 0, Classe predetta = 0
# Campione 373: Classe vera = 1, Classe predetta = 2
# Campione 374: Classe vera = 4, Classe predetta = 0
# Campione 375: Classe vera = 4, Classe predetta = 0
# Campione 376: Classe vera = 3, Classe predetta = 0
# Campione 377: Classe vera = 4, Classe predetta = 2
# Campione 378: Classe vera = 1, Classe predetta = 3
# Campione 379: Classe vera = 4, Classe predetta = 2
# Campione 380: Classe vera = 3, Classe predetta = 0
# Campione 381: Classe vera = 0, Classe predetta = 2
# Campione 382: Classe vera = 3, Classe predetta = 1
# Campione 383: Classe vera = 0, Classe predetta = 0
# Campione 384: Classe vera = 4, Classe predetta = 2
# Campione 385: Classe vera = 1, Classe predetta = 3
# Campione 386: Classe vera = 0, Classe predetta = 0
# Campione 387: Classe vera = 1, Classe predetta = 0
# Campione 388: Classe vera = 3, Classe predetta = 0
# Campione 389: Classe vera = 0, Classe predetta = 4
# Campione 390: Classe vera = 0, Classe predetta = 3
# Campione 391: Classe vera = 0, Classe predetta = 0
# Campione 392: Classe vera = 1, Classe predetta = 3
# Campione 393: Classe vera = 4, Classe predetta = 0
# Campione 394: Classe vera = 2, Classe predetta = 4
# Campione 395: Classe vera = 0, Classe predetta = 0
# Campione 396: Classe vera = 0, Classe predetta = 0
# Campione 397: Classe vera = 4, Classe predetta = 0
# Campione 398: Classe vera = 1, Classe predetta = 3
# Campione 399: Classe vera = 0, Classe predetta = 3
# Campione 400: Classe vera = 1, Classe predetta = 1
# Campione 401: Classe vera = 4, Classe predetta = 2
# Campione 402: Classe vera = 1, Classe predetta = 4
# Campione 403: Classe vera = 0, Classe predetta = 2
# Campione 404: Classe vera = 3, Classe predetta = 2
# Campione 405: Classe vera = 0, Classe predetta = 0
# Campione 406: Classe vera = 0, Classe predetta = 0
# Campione 407: Classe vera = 4, Classe predetta = 0
# Campione 408: Classe vera = 0, Classe predetta = 4
# Campione 409: Classe vera = 0, Classe predetta = 0
# Campione 410: Classe vera = 4, Classe predetta = 3
# Campione 411: Classe vera = 3, Classe predetta = 1
# Campione 412: Classe vera = 0, Classe predetta = 3
# Campione 413: Classe vera = 1, Classe predetta = 1
# Campione 414: Classe vera = 3, Classe predetta = 1
# Campione 415: Classe vera = 1, Classe predetta = 0
# Campione 416: Classe vera = 0, Classe predetta = 0
# Campione 417: Classe vera = 0, Classe predetta = 1
# Campione 418: Classe vera = 4, Classe predetta = 0
# Campione 419: Classe vera = 1, Classe predetta = 0
# Campione 420: Classe vera = 4, Classe predetta = 1
# Campione 421: Classe vera = 4, Classe predetta = 0
# Campione 422: Classe vera = 3, Classe predetta = 1
# Campione 423: Classe vera = 1, Classe predetta = 2
# Campione 424: Classe vera = 3, Classe predetta = 4
# Campione 425: Classe vera = 4, Classe predetta = 4
# Campione 426: Classe vera = 0, Classe predetta = 0
# Campione 427: Classe vera = 0, Classe predetta = 0
# Campione 428: Classe vera = 0, Classe predetta = 0
# Campione 429: Classe vera = 1, Classe predetta = 0
# Campione 430: Classe vera = 1, Classe predetta = 4
# Campione 431: Classe vera = 4, Classe predetta = 4
# Campione 432: Classe vera = 1, Classe predetta = 1
# Campione 433: Classe vera = 0, Classe predetta = 0
# Campione 434: Classe vera = 1, Classe predetta = 0
# Campione 435: Classe vera = 0, Classe predetta = 3
# Campione 436: Classe vera = 0, Classe predetta = 4
# Campione 437: Classe vera = 0, Classe predetta = 0
# Campione 438: Classe vera = 0, Classe predetta = 2
# Campione 439: Classe vera = 0, Classe predetta = 1
# Campione 440: Classe vera = 0, Classe predetta = 0
# Campione 441: Classe vera = 4, Classe predetta = 1
# Campione 442: Classe vera = 1, Classe predetta = 4
# Campione 443: Classe vera = 0, Classe predetta = 0
# Campione 444: Classe vera = 3, Classe predetta = 2
# Campione 445: Classe vera = 3, Classe predetta = 4
# Campione 446: Classe vera = 4, Classe predetta = 0
# Campione 447: Classe vera = 1, Classe predetta = 1
# Campione 448: Classe vera = 0, Classe predetta = 4
# Campione 449: Classe vera = 4, Classe predetta = 4
# Campione 450: Classe vera = 0, Classe predetta = 0
# Campione 451: Classe vera = 1, Classe predetta = 4
# Campione 452: Classe vera = 1, Classe predetta = 0
# Campione 453: Classe vera = 1, Classe predetta = 4
# Campione 454: Classe vera = 0, Classe predetta = 4
# Campione 455: Classe vera = 1, Classe predetta = 1
# Campione 456: Classe vera = 1, Classe predetta = 0
# Campione 457: Classe vera = 3, Classe predetta = 4
# Campione 458: Classe vera = 1, Classe predetta = 1
# Campione 459: Classe vera = 1, Classe predetta = 2
# Campione 460: Classe vera = 0, Classe predetta = 0
# Campione 461: Classe vera = 0, Classe predetta = 0
# Campione 462: Classe vera = 4, Classe predetta = 4
# Campione 463: Classe vera = 3, Classe predetta = 0
# Campione 464: Classe vera = 1, Classe predetta = 2
# Campione 465: Classe vera = 0, Classe predetta = 0
# Campione 466: Classe vera = 4, Classe predetta = 4
# Campione 467: Classe vera = 0, Classe predetta = 1
# Campione 468: Classe vera = 4, Classe predetta = 4
# Campione 469: Classe vera = 3, Classe predetta = 1
# Campione 470: Classe vera = 0, Classe predetta = 0
# Campione 471: Classe vera = 1, Classe predetta = 2
# Campione 472: Classe vera = 0, Classe predetta = 2
# Campione 473: Classe vera = 1, Classe predetta = 0
# Campione 474: Classe vera = 0, Classe predetta = 0
# Campione 475: Classe vera = 4, Classe predetta = 4
# Campione 476: Classe vera = 4, Classe predetta = 4
# Campione 477: Classe vera = 4, Classe predetta = 0
# Campione 478: Classe vera = 0, Classe predetta = 0
# Campione 479: Classe vera = 4, Classe predetta = 1
# Campione 480: Classe vera = 0, Classe predetta = 2
# Campione 481: Classe vera = 0, Classe predetta = 0
# Campione 482: Classe vera = 0, Classe predetta = 0
# Campione 483: Classe vera = 4, Classe predetta = 0
# Campione 484: Classe vera = 1, Classe predetta = 0
# Campione 485: Classe vera = 3, Classe predetta = 2
# Campione 486: Classe vera = 0, Classe predetta = 0
# Campione 487: Classe vera = 0, Classe predetta = 0
# Campione 488: Classe vera = 2, Classe predetta = 3
# Campione 489: Classe vera = 3, Classe predetta = 2
# Campione 490: Classe vera = 1, Classe predetta = 4
# Campione 491: Classe vera = 0, Classe predetta = 0
# Campione 492: Classe vera = 0, Classe predetta = 0
# Campione 493: Classe vera = 0, Classe predetta = 3
# Campione 494: Classe vera = 0, Classe predetta = 3
# Campione 495: Classe vera = 0, Classe predetta = 0
# Campione 496: Classe vera = 0, Classe predetta = 0
# Campione 497: Classe vera = 1, Classe predetta = 0
# Campione 498: Classe vera = 3, Classe predetta = 3
# Campione 499: Classe vera = 4, Classe predetta = 3
# Campione 500: Classe vera = 4, Classe predetta = 0
# Campione 501: Classe vera = 0, Classe predetta = 4
# Campione 502: Classe vera = 0, Classe predetta = 0
# Campione 503: Classe vera = 0, Classe predetta = 0
# Campione 504: Classe vera = 1, Classe predetta = 0
# Campione 505: Classe vera = 0, Classe predetta = 0
# Campione 506: Classe vera = 4, Classe predetta = 1
# Campione 507: Classe vera = 1, Classe predetta = 0
# Campione 508: Classe vera = 0, Classe predetta = 1
# Campione 509: Classe vera = 1, Classe predetta = 0
# Campione 510: Classe vera = 0, Classe predetta = 0
# Campione 511: Classe vera = 0, Classe predetta = 0
# Campione 512: Classe vera = 0, Classe predetta = 1
# Campione 513: Classe vera = 4, Classe predetta = 2
# Campione 514: Classe vera = 0, Classe predetta = 0
# Campione 515: Classe vera = 4, Classe predetta = 3
# Campione 516: Classe vera = 3, Classe predetta = 3
# Campione 517: Classe vera = 4, Classe predetta = 0
# Campione 518: Classe vera = 1, Classe predetta = 0
# Campione 519: Classe vera = 0, Classe predetta = 0
# Campione 520: Classe vera = 1, Classe predetta = 1
# Campione 521: Classe vera = 3, Classe predetta = 0
# Campione 522: Classe vera = 2, Classe predetta = 0
# Campione 523: Classe vera = 4, Classe predetta = 0
# Campione 524: Classe vera = 0, Classe predetta = 0
# Campione 525: Classe vera = 0, Classe predetta = 0
# Campione 526: Classe vera = 0, Classe predetta = 2
# Campione 527: Classe vera = 4, Classe predetta = 4
# Campione 528: Classe vera = 1, Classe predetta = 0
# Campione 529: Classe vera = 1, Classe predetta = 0
# Campione 530: Classe vera = 0, Classe predetta = 0
# Campione 531: Classe vera = 4, Classe predetta = 2
# Campione 532: Classe vera = 4, Classe predetta = 0
# Campione 533: Classe vera = 0, Classe predetta = 0
# Campione 534: Classe vera = 1, Classe predetta = 3
# Campione 535: Classe vera = 4, Classe predetta = 4
# Campione 536: Classe vera = 0, Classe predetta = 0
# Campione 537: Classe vera = 0, Classe predetta = 0
# Campione 538: Classe vera = 4, Classe predetta = 4
# Campione 539: Classe vera = 1, Classe predetta = 1
# Campione 540: Classe vera = 0, Classe predetta = 0
# Campione 541: Classe vera = 1, Classe predetta = 2
# Campione 542: Classe vera = 0, Classe predetta = 4
# Campione 543: Classe vera = 1, Classe predetta = 1
# Campione 544: Classe vera = 0, Classe predetta = 2
# Campione 545: Classe vera = 4, Classe predetta = 4
# Campione 546: Classe vera = 0, Classe predetta = 0
# Accuracy Finale: 34.62%
# fine evaluate predictions full e text loss

# %%
if RECONSTRUCT_IMAGES:

    class VAEImageReconstructor(nn.Module):
        def __init__(self, latent_dim=256, image_size=384, num_upscales=5):
            super(VAEImageReconstructor, self).__init__()
            
            self.image_size = image_size
            self.num_upscales = num_upscales
            self.base_size = image_size // (2 ** num_upscales)
            
            self.fc_mu = nn.Linear(2048, latent_dim)
            self.fc_logvar = nn.Linear(2048, latent_dim)
            
            self.decoder_input = nn.Linear(latent_dim, 512 * self.base_size * self.base_size)
            
            self.decoder = nn.Sequential(
                nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1), 
                nn.BatchNorm2d(256),
                nn.ReLU(True),
                
                nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1), 
                nn.BatchNorm2d(128),
                nn.ReLU(True),
                
                nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),   
                nn.BatchNorm2d(64),
                nn.ReLU(True),
                
                nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1),    
                nn.BatchNorm2d(32),
                nn.ReLU(True),
                
                nn.ConvTranspose2d(32, 3, kernel_size=4, stride=2, padding=1),     
                nn.Sigmoid()
            )

        def encode(self, features):
            mu = self.fc_mu(features)
            logvar = self.fc_logvar(features)
            return mu, logvar

        def reparameterize(self, mu, logvar):
            std = torch.exp(0.5 * logvar)
            eps = torch.randn_like(std)
            return mu + eps * std

        def decode(self, z):
            x = self.decoder_input(z)
            x = x.view(-1, 512, self.base_size, self.base_size)
            x = self.decoder(x)
            return x

        def forward(self, features):
            mu, logvar = self.encode(features)
            z = self.reparameterize(mu, logvar)
            recons = self.decode(z)
            return recons, mu, logvar


    print("fine VAE ENCODER DECLARATION (modificato per ricostruire entrambe le viste)")

    encoder_vae = ResNetEncoder(trainable_layers=ENCODER_VAE_TRAINABLE_LAYERS).to(device)

    vae = VAEImageReconstructor(latent_dim=LATENT_DIM_VAE).to(device)

    optimizer_vae = torch.optim.Adam(
        list(encoder_vae.parameters()) + list(vae.parameters()),
        lr=LEARNING_RATE_VAE
    )

    def vae_loss_function(recons, original, mu, logvar, beta=1.0):
        recons_loss = F.mse_loss(recons, original, reduction='sum') / original.size(0)
        kld_loss = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp()) / original.size(0)
        return recons_loss + beta * kld_loss, recons_loss, kld_loss

    scaler = torch.cuda.amp.GradScaler()

    if TRAIN_VAE:
        best_val_loss_vae = float('inf')
        epochs_without_improve_vae = 0

        scheduler_vae = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer_vae, mode='min', factor=0.5, patience=2, verbose=True
        )

        for epoch in range(NUM_EPOCHS_VAE):
            encoder_vae.train()
            vae.train()
            running_loss = 0.0

            for batch in train_loader:
                front_imgs = batch['front_pixel_values'].to(device)
                lateral_imgs = batch['lateral_pixel_values'].to(device)

                optimizer_vae.zero_grad()
                with torch.cuda.amp.autocast():
                    # Elaborazione delle immagini frontali
                    features_front = encoder_vae(front_imgs)
                    recons_front, mu_front, logvar_front = vae(features_front)
                    loss_front, _, _ = vae_loss_function(recons_front, front_imgs, mu_front, logvar_front)
                    # Elaborazione delle immagini laterali
                    features_lateral = encoder_vae(lateral_imgs)
                    recons_lateral, mu_lateral, logvar_lateral = vae(features_lateral)
                    loss_lateral, _, _ = vae_loss_function(recons_lateral, lateral_imgs, mu_lateral, logvar_lateral)
                    # Loss totale media
                    loss = (loss_front + loss_lateral) / 2

                scaler.scale(loss).backward()
                scaler.step(optimizer_vae)
                scaler.update()

                running_loss += loss.item()

            avg_train_loss = running_loss / len(train_loader)

            # Valutazione sul validation set
            encoder_vae.eval()
            vae.eval()
            val_loss = 0.0
            with torch.no_grad():
                for batch in val_loader:
                    front_imgs = batch['front_pixel_values'].to(device)
                    lateral_imgs = batch['lateral_pixel_values'].to(device)
                    with torch.cuda.amp.autocast():
                        features_front = encoder_vae(front_imgs)
                        recons_front, mu_front, logvar_front = vae(features_front)
                        loss_front, _, _ = vae_loss_function(recons_front, front_imgs, mu_front, logvar_front)

                        features_lateral = encoder_vae(lateral_imgs)
                        recons_lateral, mu_lateral, logvar_lateral = vae(features_lateral)
                        loss_lateral, _, _ = vae_loss_function(recons_lateral, lateral_imgs, mu_lateral, logvar_lateral)

                        loss = (loss_front + loss_lateral) / 2
                    val_loss += loss.item()
            avg_val_loss = val_loss / len(val_loader)

            scheduler_vae.step(avg_val_loss)

            print(f"[VAE] Epoch {epoch+1}/{NUM_EPOCHS_VAE} - Train Loss: {avg_train_loss:.4f} - Val Loss: {avg_val_loss:.4f}")

            # Early stopping
            if avg_val_loss < best_val_loss_vae:
                best_val_loss_vae = avg_val_loss
                epochs_without_improve_vae = 0
                best_encoder_state = encoder_vae.state_dict()
                best_vae_state = vae.state_dict()
            else:
                epochs_without_improve_vae += 1
                if epochs_without_improve_vae >= EARLY_STOPPING_PATIENCE_VAE:
                    print(f"Early stopping attivato per il VAE dopo {epoch+1} epoche senza miglioramento.")
                    break

        os.makedirs(MODEL_SAVE_DIR, exist_ok=True)
        torch.save({
            'encoder_vae_state_dict': best_encoder_state,
            'vae_state_dict': best_vae_state,
        }, VAE_MODEL_PATH)
        print(f"VAE model saved to {VAE_MODEL_PATH}")
    else:
        checkpoint = torch.load(VAE_MODEL_PATH, map_location=device)
        encoder_vae.load_state_dict(checkpoint['encoder_vae_state_dict'])
        vae.load_state_dict(checkpoint['vae_state_dict'])
        print("VAE model loaded from saved checkpoint.")

    encoder_vae.eval()
    vae.eval()

    sample = test_ds[0]
    front_img = sample['front_pixel_values'].unsqueeze(0).to(device)
    lateral_img = sample['lateral_pixel_values'].unsqueeze(0).to(device)

    with torch.no_grad():
        feat_front = encoder_vae(front_img)
        recons_front, _, _ = vae(feat_front)

        feat_lateral = encoder_vae(lateral_img)
        recons_lateral, _, _ = vae(feat_lateral)


    plt.figure(figsize=(8, 4))
    plt.subplot(1, 2, 1)
    orig_front = front_img.squeeze(0).permute(1, 2, 0).cpu().numpy()
    plt.imshow(orig_front)
    plt.title("Front Originale")
    plt.axis('off')
    plt.subplot(1, 2, 2)
    rec_front = recons_front.squeeze(0).permute(1, 2, 0).cpu().numpy()
    plt.imshow(rec_front)
    plt.title("Front Ricostruita")
    plt.axis('off')
    plt.show()

    plt.figure(figsize=(8, 4))
    plt.subplot(1, 2, 1)
    orig_lateral = lateral_img.squeeze(0).permute(1, 2, 0).cpu().numpy()
    plt.imshow(orig_lateral)
    plt.title("Laterale Originale")
    plt.axis('off')
    plt.subplot(1, 2, 2)
    rec_lateral = recons_lateral.squeeze(0).permute(1, 2, 0).cpu().numpy()
    plt.imshow(rec_lateral)
    plt.title("Laterale Ricostruita")
    plt.axis('off')
    plt.show()

    print("fine VAE e visualizzazione ricostruzioni (modificato per frontale e laterale)")
# Out:
# fine VAE ENCODER DECLARATION (modificato per ricostruire entrambe le viste)
# [VAE] Epoch 1/10 - Train Loss: 26932.0382 - Val Loss: 14570.0500
# [VAE] Epoch 2/10 - Train Loss: 11955.4051 - Val Loss: 8425.4671
# [VAE] Epoch 3/10 - Train Loss: 8963.7133 - Val Loss: 7338.8510
# [VAE] Epoch 4/10 - Train Loss: 7677.3042 - Val Loss: 7038.8096
# [VAE] Epoch 5/10 - Train Loss: 6837.0235 - Val Loss: 6462.3572
# [VAE] Epoch 6/10 - Train Loss: 6283.6952 - Val Loss: 5753.7956
# [VAE] Epoch 7/10 - Train Loss: 5777.4676 - Val Loss: 5574.5424
# [VAE] Epoch 8/10 - Train Loss: 5415.2712 - Val Loss: 5259.6295
# [VAE] Epoch 9/10 - Train Loss: 5146.0570 - Val Loss: 5063.7318
# [VAE] Epoch 10/10 - Train Loss: 4932.3560 - Val Loss: 4858.9039
# VAE model saved to ./saved_model/vae.pth
# fine VAE e visualizzazione ricostruzioni (modificato per frontale e laterale)
